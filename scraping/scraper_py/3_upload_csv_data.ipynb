# %%
import csv
import pandas as pd
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="NYg1@nts",
  database="NRL_data"
)
mycursor = mydb.cursor()

# %%
stat_df = pd.read_csv('./csv_files/2019_03_data.csv')
stat_df = pd.read_csv('./csv_files/2019_03_data.csv', index_col='index').drop(columns='Unnamed: 0')
stat_df.head()
# Out:
#                       player_id  team_id  match_id  number  position  \
# index
# Connor_Watson_8             208        8       194       1  Fullback
# Edrick_Lee_8                214        8       194       2    Winger
# Hymel_Hunt_8                218        8       194       3    Centre
# Jesse_Ramien_8              215        8       194       4    Centre
# Shaun_Kenny-dowall_8        212        8       194       5    Winger
#
#                      minutes_played  points  tries  conversions  \
# index
# Connor_Watson_8               80:00       0      0            0
# Edrick_Lee_8                  80:00       4      1            0
# Hymel_Hunt_8                  80:00       0      0            0
# Jesse_Ramien_8                80:00       0      0            0
# Shaun_Kenny-dowall_8          80:00       0      0            0
#
#                       conversion_attempts  ...  kicked_dead errors  \
# index                                      ...
# Connor_Watson_8                         0  ...            0      1
# Edrick_Lee_8                            0  ...            0      1
# Hymel_Hunt_8                            0  ...            0      0
# Jesse_Ramien_8                          0  ...            0      1
# Shaun_Kenny-dowall_8                    0  ...            0      1
#
#                       handling_errors  one_on_ones_lost  penalties  on_report  \
# index
# Connor_Watson_8                     1                 0          0          0
# Edrick_Lee_8                        2                 0          0          0
# Hymel_Hunt_8                        0                 0          0          0
# Jesse_Ramien_8                      1                 0          0          0
# Shaun_Kenny-dowall_8                1                 0          0          0
#
#                       sin_bins  send_offs  stint_one  stint_two
# index
# Connor_Watson_8              0          0      80:00          0
# Edrick_Lee_8                 0          0      80:00          0
# Hymel_Hunt_8                 0          0      80:00          0
# Jesse_Ramien_8               0          0      80:00          0
# Shaun_Kenny-dowall_8         0          0      80:00          0
#
# [5 rows x 57 columns]

# %%
def find_position_id(name):
    find_position_query = 'SELECT id FROM Positions WHERE position_name = %s;'
    mycursor.execute(find_position_query, (name,))
    return mycursor.fetchone()[0]

# %%
for column in ['conversion_percentage', 'tackle_percentage']:
    stat_df[column] = stat_df[column].str.replace('%', '').astype('float') / 100
    stat_df[column] = stat_df[column].round(3)
stat_df['average_play_the_ball_seconds'] = stat_df['average_play_the_ball_seconds'].str.replace('s', '').astype('float')
stat_df['position_id'] = stat_df['position'].apply(find_position_id)
stat_df.head()
# Out:
#                       player_id  team_id  match_id  number  position  \
# index
# Connor_Watson_8             208        8       194       1  Fullback
# Edrick_Lee_8                214        8       194       2    Winger
# Hymel_Hunt_8                218        8       194       3    Centre
# Jesse_Ramien_8              215        8       194       4    Centre
# Shaun_Kenny-dowall_8        212        8       194       5    Winger
#
#                      minutes_played  points  tries  conversions  \
# index
# Connor_Watson_8               80:00       0      0            0
# Edrick_Lee_8                  80:00       4      1            0
# Hymel_Hunt_8                  80:00       0      0            0
# Jesse_Ramien_8                80:00       0      0            0
# Shaun_Kenny-dowall_8          80:00       0      0            0
#
#                       conversion_attempts  ...  errors  handling_errors  \
# index                                      ...
# Connor_Watson_8                         0  ...       1                1
# Edrick_Lee_8                            0  ...       1                2
# Hymel_Hunt_8                            0  ...       0                0
# Jesse_Ramien_8                          0  ...       1                1
# Shaun_Kenny-dowall_8                    0  ...       1                1
#
#                       one_on_ones_lost  penalties  on_report  sin_bins  \
# index
# Connor_Watson_8                      0          0          0         0
# Edrick_Lee_8                         0          0          0         0
# Hymel_Hunt_8                         0          0          0         0
# Jesse_Ramien_8                       0          0          0         0
# Shaun_Kenny-dowall_8                 0          0          0         0
#
#                       send_offs  stint_one  stint_two  position_id
# index
# Connor_Watson_8               0      80:00          0            1
# Edrick_Lee_8                  0      80:00          0            2
# Hymel_Hunt_8                  0      80:00          0            3
# Jesse_Ramien_8                0      80:00          0            3
# Shaun_Kenny-dowall_8          0      80:00          0            2
#
# [5 rows x 58 columns]

# %%
def convert_time_columns_to_numeric(x):
    x = x.split(':')
    minutes = x[0]
    try:
        seconds = x[1]
    except:
        seconds = 0
    return round(((int(minutes) * 60) + int(seconds)) / 60, 2)
    
for column in ['minutes_played', 'stint_one', 'stint_two']:
    stat_df[column] = stat_df[column].apply(lambda x: convert_time_columns_to_numeric(x))

# %%
stat_df['player_id'] = stat_df['player_id'].astype('int')

# %%
stat_df.head()
# Out:
#                       player_id  team_id  match_id  number  position  \
# index
# Connor_Watson_8             208        8       194       1  Fullback
# Edrick_Lee_8                214        8       194       2    Winger
# Hymel_Hunt_8                218        8       194       3    Centre
# Jesse_Ramien_8              215        8       194       4    Centre
# Shaun_Kenny-dowall_8        212        8       194       5    Winger
#
#                       minutes_played  points  tries  conversions  \
# index
# Connor_Watson_8                 80.0       0      0            0
# Edrick_Lee_8                    80.0       4      1            0
# Hymel_Hunt_8                    80.0       0      0            0
# Jesse_Ramien_8                  80.0       0      0            0
# Shaun_Kenny-dowall_8            80.0       0      0            0
#
#                       conversion_attempts  ...  errors  handling_errors  \
# index                                      ...
# Connor_Watson_8                         0  ...       1                1
# Edrick_Lee_8                            0  ...       1                2
# Hymel_Hunt_8                            0  ...       0                0
# Jesse_Ramien_8                          0  ...       1                1
# Shaun_Kenny-dowall_8                    0  ...       1                1
#
#                       one_on_ones_lost  penalties  on_report  sin_bins  \
# index
# Connor_Watson_8                      0          0          0         0
# Edrick_Lee_8                         0          0          0         0
# Hymel_Hunt_8                         0          0          0         0
# Jesse_Ramien_8                       0          0          0         0
# Shaun_Kenny-dowall_8                 0          0          0         0
#
#                       send_offs  stint_one  stint_two  position_id
# index
# Connor_Watson_8               0       80.0        0.0            1
# Edrick_Lee_8                  0       80.0        0.0            2
# Hymel_Hunt_8                  0       80.0        0.0            3
# Jesse_Ramien_8                0       80.0        0.0            3
# Shaun_Kenny-dowall_8          0       80.0        0.0            2
#
# [5 rows x 58 columns]

# %% [markdown]
# ## Insert data into database

# %%
insert_query = '''INSERT INTO PlayerMatchStats (match_id, player_id, team_id, position_id, minutes_played,
    points, tries, conversions, conversion_attempts, penalty_goals,
    conversion_percentage, field_goals, total_runs, total_run_metres, kick_return_metres,
    post_contact_metres, line_breaks, line_break_assists, try_assists, line_engaged_runs,
    tackle_breaks, hit_ups, play_the_ball, average_play_ball_seconds, dummy_half_runs,
    dummy_half_run_metres, steals, offloads, dummy_passes, passes,
    receipts, pass_to_run_ratio, tackle_percentage, tackles_made, tackles_missed, ineffective_tackles,
    intercepts, kicks_defused, kicks, kicking_metres, forced_drop_outs,
    bomb_kicks, grubbers, fourty_twenty, cross_field_kicks, kicked_dead,
    errors, handling_errors, one_on_ones_lost, penalties, on_report,
    sin_bins, send_offs, stint_one, stint_two)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s,
    # %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s,
    # %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);
    '''

# %%
for row in stat_df.iterrows():
    r = row[1]
    insert_tuple = (r['match_id'],
r['player_id'],
r['team_id'],
r['position_id'],
r['minutes_played'],
r['points'],
r['tries'],
r['conversions'],
r['conversion_attempts'],
r['penalty_goals'],
r['conversion_percentage'],
r['field_goals'],
r['total_runs'],
r['total_run_metres'],
r['kick_return_metres'],
r['post_contact_metres'],
r['line_breaks'],
r['line_break_assists'],
r['try_assists'],
r['line_engaged_runs'],
r['tackle_breaks'],
r['hit_ups'],
r['play_the_ball'],
r['average_play_the_ball_seconds'],
r['dummy_half_runs'],
r['dummy_half_run_metres'],
r['steals'],
r['offloads'],
r['dummy_passes'],
r['passes'],
r['receipts'],
r['pass_to_run_ratio'],
r['tackle_percentage'],
r['tackles_made'],
r['tackles_missed'],
r['ineffective_tackles'],
r['intercepts'],
r['kicks_defused'],
r['kicks'],
r['kicking_metres'],
r['forced_drop_outs'],
r['bomb_kicks'],
r['grubbers'],
r['fourty_twenty'],
r['cross_field_kicks'],
r['kicked_dead'],
r['errors'],
r['handling_errors'],
r['one_on_ones_lost'],
r['penalties'],
r['on_report'],
r['sin_bins'],
r['send_offs'],
r['stint_one'],
r['stint_two'])
    print(row[0])
    try:
        mycursor.execute(insert_query, insert_tuple)
        mydb.commit()
        #print('success!')
    except:
        print('error: ' + str(row[0]) + ' match_id = ' + str(r['match_id']))
# Out:
# Billy_Slater_7
# success!
# Suliasi_Vunivalu_7
# success!
# Cheyse_Blair_7
# success!
# Curtis_Scott_7
# success!
# Josh_Addo-carr_7
# success!
# Cameron_Munster_7
# success!
# Jesse_Bromwich_7
# success!
# Cameron_Smith_7
# success!
# Tim_Glasby_7
# success!
# Felise_Kaufusi_7
# success!
# Joe_Stimson_7
# success!
# Dale_Finucane_7
# success!
# Brandon_Smith_7
# success!
# Christian_Welch_7
# success!
# Kenneath_Bromwich_7
# success!
# Brodie_Croft_7
# success!
# Sam_Kasiano_7
# success!
# Alex_Johnston_13
# success!
# Campbell_Graham_13
# success!
# Greg_Inglis_13
# success!
# Dane_Gagai_13
# success!
# Robert_Jennings_13
# success!
# Cody_Walker_13
# success!
# Adam_Reynolds_13
# success!
# Thomas_Burgess_13
# success!
# Damien_Cook_13
# success!
# George_Burgess_13
# success!
# John_Sutton_13
# success!
# Angus_Crichton_13
# success!
# Sam_Burgess_13
# success!
# Hymel_Hunt_13
# success!
# Cameron_Murray_13
# success!
# Jason_Clark_13
# success!
# Dean_Britt_13
# success!
# Dallin_Watene-zelezniak_12
