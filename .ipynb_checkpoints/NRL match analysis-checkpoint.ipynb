# %% [markdown]
# # NRL Team of the Year Analysis

# %% [markdown]
# The Dally M Team of the Year is the National Rugby League of Australia's equivalent to an all-Pro team in American sports.  Each week, journalists and commentators across Australia pick their team of the week and at the end of the season, the votes are combined to select a Team of the Year.  Since most of the people voting on team of the week are doing so subjectively, there is often a bit controversy when the Dally M Team of the Year is revealed at the end of the season.  Last year is a prime example:
#
# https://www.sportingnews.com/au/league/news/dally-m-awards-fans-blow-up-over-dally-m-team-of-the-year-selections/1mds08rg0caso1afr28idjyzyo
#
# While 6 of the 9 selections in 2018's Team of the Year were well received, there was plenty of outrage on social media over the selections of Joseph Leilua (centre), Luke Brooks (halfback) and Josh Jackson (second-row).
#
#
# In this analysis I will look into data from the 2018 NRL season to determine whether or not the Dally M Team of the Year was an accurate reflection of player performance.  The data I'm using was scraped from the official NRL website (www.nrl.com) using Selenium and Python's BeautifulSoup library and compiled into a database.  The database contains detailed player stats from every match.  In order to determine whether or not a player deserved to be in Team of the Year, I will first analyze various stats to determine which were the most highly correlated with a team's number of wins over the course of the season.  Once I've determined which stats are most important in contributing to a victory, I will compare players at each position by these stats to determine who deserved to be in 2018's Team of the Year.

# %%
#Deep analysis...try to see who came in 1st, 2nd, 3rd each week

# %%
#Import Pandas and connect to database
import pandas as pd
import mysql.connector as sql

mydb = sql.connect(
  host="localhost",
  user="root",
  passwd="NYg1@nts",
  database="NRL_data"
)

#Function to easily create dataframes from SQL query results
def create_df(query):
    return pd.read_sql_query(query, con=mydb)

# %% [markdown]
# # Final Standings

# %% [markdown]
# In order to determine which stats have the strongest correlation with total wins, I will put together an easy to read final standings list from the 2018 season.  The database contains entries for each individual match but does not aggregate wins or point differential for each team.

# %%
# Replace team_ids in Matches table with with team names from Teams table
match_query = '''SELECT m.id, m.round, m.date,
CASE
	WHEN m.home_team_id = m.winner THEN home.nickname
    ELSE away.nickname
END winner,
CASE
	WHEN m.home_team_id = m.winner THEN m.home_score
    ELSE m.away_score
END winning_score,
CASE
	WHEN m.home_team_id = m.winner THEN away.nickname
    ELSE home.nickname
END loser,
CASE
	WHEN m.home_team_id = m.winner THEN m.away_score
    ELSE m.home_score
END losing_score, home.nickname home, away.nickname away
FROM Matches m
JOIN Teams home
ON m.home_team_id = home.id
JOIN Teams away
ON m.away_team_id = away.id
WHERE year(m.date) = 2018
ORDER BY date;'''
matches_df = create_df(match_query)
matches_df.head()
# Out:
#    id  round        date    winner  winning_score       loser  losing_score  \
# 0   1      1  2018-03-08   Dragons             34     Broncos            12
# 1   2      1  2018-03-09   Knights             19  Sea Eagles            18
# 2   3      1  2018-03-09   Cowboys             20      Sharks            14
# 3   6      1  2018-03-10     Storm             36    Bulldogs            18
# 4   5      1  2018-03-10  Warriors             32   Rabbitohs            20
#
#         home        away
# 0    Dragons     Broncos
# 1    Knights  Sea Eagles
# 2    Cowboys      Sharks
# 3   Bulldogs       Storm
# 4  Rabbitohs    Warriors

# %%
#Create dataframe that combines points_scored and points_allowed in each team's victory
winners = matches_df.groupby('winner')
w_scored = winners['winning_score'].sum()
w_allowed = winners['losing_score'].sum()

#Create dataframe that combines points_scored and points_allowed in each team's loss
losers = matches_df.groupby('loser')
l_scored = losers['losing_score'].sum()
l_allowed = losers['winning_score'].sum()

#Combine dataframes
total_scores = pd.concat([w_scored, l_scored, w_allowed, l_allowed], axis=1, join='inner')
total_scores.columns = ['scored_in_win', 'scored_in_loss', 'allowed_in_win', 'allowed_in_loss']
total_scores.head(2)

#Calculate total points_differential, points_scored and points_allowed for each team
total_scores['pts_scored'] = total_scores['scored_in_win'] + total_scores['scored_in_loss']
total_scores['pts_allowed'] = total_scores['allowed_in_win'] + total_scores['allowed_in_loss']
total_scores['pts_differential'] = total_scores['pts_scored'] - total_scores['pts_allowed']
total_points_data = total_scores[['pts_differential', 'pts_scored', 'pts_allowed']]
total_points_data.head()
# Out:
#           pts_differential  pts_scored  pts_allowed
# Broncos                 56         556          500
# Bulldogs               -46         428          474
# Cowboys                -72         449          521
# Dragons                 47         519          472
# Eels                  -176         374          550

# %%
#Aggreate win / loss records for each team
win_loss_query = '''SELECT t.nickname team,
    count(m.winner) as wins,
    24 - count(m.winner) as loses
FROM Matches m
JOIN Teams t
ON m.winner = t.id
WHERE year(m.date) = 2018
GROUP BY m.winner
ORDER BY wins DESC;'''
win_loss_df = create_df(win_loss_query).set_index('team')
win_loss_df.head()
# Out:
#            wins  loses
# team
# Roosters     16      8
# Rabbitohs    16      8
# Storm        16      8
# Sharks       16      8
# Dragons      15      9

# %%
#Combine win/loss records with point differentials to create final standings
final_standings = pd.concat([win_loss_df, total_points_data], axis=1, join='inner').sort_values(['wins', 'pts_differential'], ascending=[0,0])
final_standings
# Out:
#             wins  loses  pts_differential  pts_scored  pts_allowed
# Roosters      16      8               181         542          361
# Storm         16      8               173         536          363
# Rabbitohs     16      8               145         582          437
# Sharks        16      8                96         519          423
# Broncos       15      9                56         556          500
# Panthers      15      9                56         517          461
# Dragons       15      9                47         519          472
# Warriors      15      9                25         472          447
# Tigers        12     12               -83         377          460
# Raiders       10     14                23         563          540
# Knights        9     15              -193         414          607
# Bulldogs       8     16               -46         428          474
# Cowboys        8     16               -72         449          521
# Titans         8     16              -110         472          582
# Sea Eagles     7     17              -122         500          622
# Eels           6     18              -176         374          550

# %%
#Visualize if points_scored correlates highly with total wins
final_standings.plot.scatter(x='wins', y='pts_scored', color='Blue', label='scored')

# %% [markdown]
# We can see that there is a very weak correlation betwen points_scored and wins. Lets look at alternative metrics and player stats to find a better correlations with win totals.

# %% [markdown]
# # Stat analyis by player

# %% [markdown]
# The PlayerMatchStats table contains one entry for each player involved in every match. We will combine each player's individual contribution into one table that aggregates each statistical category by team for the 2018 season

# %%
#Replace player_ids and team_ids with names in the PlayerMatchStats table
query = '''SELECT CONCAT(p.first_name, ' ' ,p.last_name) name, t.nickname team, p_stats.*
        FROM PlayerMatchStats p_stats
        JOIN Players p
        ON p_stats.player_id = p.id
        JOIN Teams t
        ON p_stats.team_id = t.id
        JOIN Matches m
        ON p_stats.match_id = m.id
        WHERE year(m.date) = 2018;'''

player_stat_df = create_df(query)
player_stat_df.set_index('name').head()
# Out:
#                    team  id  match_id  player_id  team_id  position_id  \
# name
# Darius Boyd     Broncos  18         1         22        1            1
# Corey Oates     Broncos  19         1         20        1            2
# James Roberts   Broncos  20         1         27        1            3
# Jordan Kahu     Broncos  21         1        251        1            3
# Jamayne Isaako  Broncos  22         1         26        1            2
#
#                 minutes_played  points  tries  conversions  ...  kicked_dead  \
# name                                                        ...
# Darius Boyd               80.0       0      0            0  ...            0
# Corey Oates               80.0       0      0            0  ...            0
# James Roberts             80.0       8      2            0  ...            0
# Jordan Kahu               80.0       4      0            1  ...            0
# Jamayne Isaako            80.0       0      0            0  ...            0
#
#                 errors handling_errors  one_on_ones_lost  penalties  \
# name
# Darius Boyd          1               1                 0          0
# Corey Oates          1               1                 0          0
# James Roberts        0               0                 0          1
# Jordan Kahu          1               1                 0          0
# Jamayne Isaako       2               0                 0          0
#
#                 on_report  sin_bins  send_offs  stint_one  stint_two
# name
# Darius Boyd             0         0          0       80.0       None
# Corey Oates             0         0          0       80.0       None
# James Roberts           0         0          0       80.0       None
# Jordan Kahu             0         0          0       80.0       None
# Jamayne Isaako          0         0          0       80.0       None
#
# [5 rows x 57 columns]

# %% [markdown]
# We can see that there are 57 columns in the player stat dataframe. We want to slim this number down to make our analysis a little more manageable.

# %%
player_stat_df.columns
# Out:
# Index(['name', 'team', 'id', 'match_id', 'player_id', 'team_id', 'position_id',
#        'minutes_played', 'points', 'tries', 'conversions',
#        'conversion_attempts', 'penalty_goals', 'conversion_percentage',
#        'field_goals', 'total_runs', 'total_run_metres', 'kick_return_metres',
#        'post_contact_metres', 'line_breaks', 'line_break_assists',
#        'try_assists', 'line_engaged_runs', 'tackle_breaks', 'hit_ups',
#        'play_the_ball', 'average_play_ball_seconds', 'dummy_half_runs',
#        'dummy_half_run_metres', 'steals', 'offloads', 'dummy_passes', 'passes',
#        'receipts', 'pass_to_run_ratio', 'tackle_percentage', 'tackles_made',
#        'tackles_missed', 'ineffective_tackles', 'intercepts', 'kicks_defused',
#        'kicks', 'kicking_metres', 'forced_drop_outs', 'bomb_kicks', 'grubbers',
#        'fourty_twenty', 'cross_field_kicks', 'kicked_dead', 'errors',
#        'handling_errors', 'one_on_ones_lost', 'penalties', 'on_report',
#        'sin_bins', 'send_offs', 'stint_one', 'stint_two'],
#       dtype='object')

# %% [markdown]
# We can see from the list of columns that almost all of the stats fall into several categories: scoring, running, kicking, defensive/tackling, and errors/penalties. To simplify the anlaysis, we will only include broader stats for each category. Using running stats as an example, we will include total_run_metres but ignore more refined stats like kick_return_metres and post_contact_metres which both are included in total_run_metres.  I will also create columns for stats like metres_per_kick and tackle_percentage which aren't included in the initial PlayerMatchStat table but can easily be calculated.

# %%
team_stats = player_stat_df.groupby('team').agg(sum)

#Combine aggregated stats with teams' win total
slimmed_team_stats = team_stats[['points', 'tries', 'try_assists', 'total_runs', 'total_run_metres', 'tackles_made', 'tackles_missed', 'ineffective_tackles',
           'kicks', 'kicking_metres', 'errors', 'penalties']]
wins = final_standings[['wins', 'pts_differential', 'pts_scored', 'pts_allowed']]
team_stats = pd.concat([wins, slimmed_team_stats], axis=1, join='inner').sort_values(['wins', 'pts_differential'], ascending=[0,0])

#Add columns for categories that calculate averages
team_stats['metres_per_kick'] = team_stats['kicking_metres'] / team_stats['kicks']
team_stats['metres_per_run'] = team_stats['total_run_metres'] / team_stats['total_runs']
team_stats['tackle_percentage'] = team_stats['tackles_made'] / (team_stats[['tackles_made', 'tackles_missed', 'ineffective_tackles']].sum(axis = 1))

team_stats
# Out:
#             wins  pts_differential  pts_scored  pts_allowed  points  tries  \
# Roosters      16               181         542          361     542     88
# Storm         16               173         536          363     552     89
# Rabbitohs     16               145         582          437     582     98
# Sharks        16                96         519          423     519     87
# Broncos       15                56         556          500     556     88
# Panthers      15                56         517          461     517     82
# Dragons       15                47         519          472     519     82
# Warriors      15                25         472          447     472     80
# Tigers        12               -83         377          460     377     61
# Raiders       10                23         563          540     563     93
# Knights        9              -193         414          607     414     73
# Bulldogs       8               -46         428          474     428     65
# Cowboys        8               -72         449          521     449     73
# Titans         8              -110         472          582     480     80
# Sea Eagles     7              -122         500          622     500     81
# Eels           6              -176         374          550     374     66
#
#             try_assists  total_runs  total_run_metres  tackles_made  \
# Roosters             75        3985             38078          7925
# Storm                60        3963             35278          7731
# Rabbitohs            75        4174             38270          7582
# Sharks               73        4168             36898          7381
# Broncos              58        3920             35810          7749
# Panthers             61        4107             36797          7624
# Dragons              56        4178             37300          7846
# Warriors             63        4036             36947          7855
# Tigers               41        3999             34998          8583
# Raiders              66        3745             34450          7315
# Knights              58        3977             33604          8101
# Bulldogs             54        4235             37506          7679
# Cowboys              62        4034             35574          7614
# Titans               59        3922             34754          7708
# Sea Eagles           61        3928             36154          7320
# Eels                 48        3977             35267          8479
#
#             tackles_missed  ineffective_tackles  kicks  kicking_metres  \
# Roosters               653                  457    443           11304
# Storm                  661                  372    427           10477
# Rabbitohs              710                  348    398           10403
# Sharks                 711                  393    414           10554
# Broncos                784                  350    459           13071
# Panthers               906                  305    414           10226
# Dragons                638                  430    445           11611
# Warriors               844                  300    416           11186
# Tigers                 957                  373    468           11911
# Raiders                804                  354    373            9442
# Knights                757                  348    412           11105
# Bulldogs               645                  398    447           10949
# Cowboys                748                  361    441            9642
# Titans                 839                  356    401            9713
# Sea Eagles             712                  378    380            8925
# Eels                   771                  372    457           11462
#
#             errors  penalties  metres_per_kick  metres_per_run  \
# Roosters       276        198        25.516930        9.555332
# Storm          255        196        24.536300        8.901842
# Rabbitohs      242        202        26.138191        9.168663
# Sharks         245        201        25.492754        8.852687
# Broncos        207        189        28.477124        9.135204
# Panthers       237        226        24.700483        8.959581
# Dragons        246        169        26.092135        8.927717
# Warriors       219        206        26.889423        9.154361
# Tigers         233        197        25.450855        8.751688
# Raiders        233        225        25.313673        9.198932
# Knights        228        191        26.953883        8.449585
# Bulldogs       225        166        24.494407        8.856198
# Cowboys        255        181        21.863946        8.818542
# Titans         263        218        24.221945        8.861295
# Sea Eagles     239        212        23.486842        9.204175
# Eels           232        200        25.080963        8.867740
#
#             tackle_percentage
# Roosters             0.877144
# Storm                0.882131
# Rabbitohs            0.877546
# Sharks               0.869888
# Broncos              0.872340
# Panthers             0.862932
# Dragons              0.880188
# Warriors             0.872875
# Tigers               0.865833
# Raiders              0.863331
# Knights              0.879970
# Bulldogs             0.880417
# Cowboys              0.872865
# Titans               0.865776
# Sea Eagles           0.870392
# Eels                 0.881210

# %%
#Visualize correlations between different statistical categories
corr = team_stats.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow0_col1 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow0_col2 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow0_col3 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow0_col4 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow0_col5 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow0_col6 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow0_col7 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow0_col8 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow0_col9 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow0_col10 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow0_col11 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow0_col12 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow0_col13 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow0_col14 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow0_col15 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow0_col16 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow0_col17 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow0_col18 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow1_col0 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow1_col2 {
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow1_col4 {
#             background-color:  #da5a49;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow1_col5 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow1_col6 {
#             background-color:  #f08b6e;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow1_col7 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow1_col8 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow1_col9 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow1_col10 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow1_col11 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow1_col12 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow1_col13 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow1_col14 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow1_col15 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow1_col16 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow1_col17 {
#             background-color:  #f7ad90;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow1_col18 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow2_col0 {
#             background-color:  #ee8468;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow2_col1 {
#             background-color:  #d95847;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow2_col3 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow2_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow2_col5 {
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow2_col6 {
#             background-color:  #e26952;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow2_col7 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow2_col8 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow2_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow2_col10 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow2_col11 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow2_col12 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow2_col13 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow2_col14 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow2_col15 {
#             background-color:  #ecd3c5;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow2_col16 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow2_col17 {
#             background-color:  #f59d7e;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow2_col18 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_efa3c2a2_b534_11e9_a94f_3af9d33c491erow3_col2 {
#             background-color:  #799cf8;

# %%
#We can see that tries, total_run_metres, metres_per_kick, low penalties, 

#Make some charts comparing points(for / against) to (metres_per_run, total_run_metres, tries, kicks, metres_per_kick,
#tackles_made, tackle_percentage)
#we don't want guys with high tackles_made...but high tackle_percentage

# %% [markdown]
# # Find each player's positions
# Will = max(position_id)
# Get rid of all players who played less than 12 games (half the season)

# %%
from scipy.stats import mode

position_df = player_stat_df[['name', 'position_id']]
modes = position_df.groupby('name')['position_id'].apply(lambda x: mode(x)[0][0]).reset_index().rename(columns={"position_id": "main_position"})
modes[:20]

player_stats_with_positions = pd.merge(modes, player_stats_grouped, how='left', on='name')

player_stats_with_positions = player_stats_with_positions.drop(columns=['match_id', 'position_id'])
player_stats_with_positions['metres_per_run'] = player_stats_with_positions['total_run_metres'] / player_stats_with_positions['total_runs']
player_stats_with_positions['metres_per_kick'] = player_stats_with_positions['kicking_metres'] / player_stats_with_positions['kicks']
player_stats_with_positions['tackle_percentage'] = player_stats_with_positions['tackles_made'] / (player_stats_with_positions['tackles_made'] + player_stats_with_positions['tackles_missed'] + player_stats_with_positions['ineffective_tackles'])

player_stats_with_positions.sort_values('name')
# Out:
#                       name  main_position     id  player_id  team_id  \
# 0               Aaron Gray              3    275         87        4
# 1              Aaron Woods              6  74391       2346       78
# 2               Adam Blair              9  69309       4840      198
# 3             Adam Doueihi             10  51667       6192      234
# 4             Adam Elliott              9  78685       1464       72
# 5            Adam Reynolds              5  75134       7245      273
# 6        Addin Fonua-blake              6  78290      12216      144
# 7           Agnatius Paasi              6  77828       4862      198
# 8             Aidan Guerra              8  77817       4512      192
# 9              Aidan Sezer              5  45611        594       36
# 10            Aiden Tolman              6  61294        992       48
# 11             Akuila Uate              2  30573       7620       90
# 12             Albert Vete             10   7886        471       25
# 13              Alex Glenn              8  64770         40       20
# 14           Alex Johnston              1  64791       7266      273
# 15               Alex Twal             10  65753       9219      336
# 16       Alexander Brimson              4  67883       1665       75
# 17           Andrew Fifita              6  74967       2369       92
# 18       Andrew McCullough              7  65474         63       21
# 19          Angus Crichton              8  70457      11638      286
# 20             Anthony Don              2  79336       2688      120
# 21         Anthony Gelling             10  15837       4095       63
# 22         Anthony Milford              4  78243        456       24
# 23     Antonio Winterstein              2  34709       8272      160
# 24         Apisai Koroisau              7  23747       1989       78
# 25           Ashley Taylor              5  79058       2599      115
# 26            Asipeli Fine             10   9698       2976       18
# 27             Ata Hingano             10  21936        350       20
# 28        Ava Seumanufagai             10  23231       1352       52
# 29              Beau Scott             10  10263       3864       77
# ..                     ...            ...    ...        ...      ...
# 408            Tohu Harris              8  40923       3744      144
# 409             Tom Opacic              3  23885       3108       12
# 410           Tom Starling             10   6372        630        8
# 411          Tom Trbojevic              1  73547       3322      132
# 412             Tom Wright              4  15805       2460       24
# 413          Tony Williams              8   7987       2935       55
# 414        Trent Hodkinson             10  68481       2736      100
# 415           Trent Merrin              6  76182      12558      276
# 416         Tui Kamikamica             10  25256        860       35
# 417       Tuimoala Lolohea              1  12552       3126       96
# 418        Tyrell Fuimaono             10  24597       2046       78
# 419             Tyrone May             10  42861       2600       96
# 420         Tyrone Peachey              4  69717       2640      264
# 421        Tyrone Phillips              2  30492       5508      108
# 422  Tyronne Roberts-davis              2   1824        604        5
# 423          Tyson Frizell              8  66120       8547      294
# 424           Tyson Gamble              4   3916        470       16
# 425       Valentine Holmes              1  74732      10856       92
# 426          Victor Radley             10  70906       9306      330
# 427          Viliame Kikau              8  74723       7866      276
# 428            Wade Graham              8  53788       8092       68
# 429             Waqa Blake              3  50906       4564      168
# 430             Wayde Egan             10  41939       6960      144
# 431          Will Chambers              3  51273       3179      119
# 432           Will Hopoate              3  78436       2016       72
# 433          Will Matthews              8  48894       8370       75
# 434             Will Smith             10  31302       3731      143
# 435       Young Tonumaipea              3  19933       4123       49
# 436              Zac Lomax              3   9064        778       28
# 437          Zane Tetevano             10  78100      10176      360
#
#      minutes_played  points  tries  conversions  conversion_attempts  ...  \
# 0              80.0       0      0            0                    0  ...
# 1            1227.0       4      1            0                    0  ...
# 2            1390.0       4      1            0                    0  ...
# 3             674.0      26      2            8                   14  ...
# 4            1063.0      16      4            0                    0  ...
# 5            1670.0     186      4           55                   82  ...
# 6            1152.0      12      3            0                    0  ...
# 7             868.0      12      3            0                    0  ...
# 8            1674.0      20      5            0                    0  ...
# 9            1380.0      21      2            6                    8  ...
# 10            889.0       0      0            0                    0  ...
# 11           1209.0      20      5            0                    0  ...
# 12             64.0       0      0            0                    0  ...
# 13           1467.0      16      4            0                    0  ...
# 14           1539.0      32      8            0                    0  ...
# 15            770.0       0      0            0                    0  ...
# 16           1179.0      28      7            0                    0  ...
# 17           1316.0      12      3            0                    0  ...
# 18           1528.0      12      3            0                    0  ...
# 19           1744.0      12      3            0                    0  ...
# 20           1924.0      60     15            0                    0  ...
# 21            268.0       8      2            0                    0  ...
# 22           1918.0      25      6            0                    0  ...
# 23           1268.0      28      7            0                    0  ...
# 24            910.0      12      3            0                    0  ...
# 25           1778.0      52      3           15                   17  ...
# 26            114.0       0      0            0                    0  ...
# 27            237.0       0      0            0                    0  ...
# 28            340.0       0      0            0                    0  ...
# 29            219.0       0      0            0                    0  ...
# ..              ...     ...    ...          ...                  ...  ...
# 408          1204.0       8      2            0                    0  ...
# 409           508.0       4      1            0                    0  ...
# 410            17.0       0      0            0                    0  ...
# 411          1712.0      36      9            0                    0  ...
# 412           165.0       4      1            0                    0  ...
# 413           258.0       0      0            0                    0  ...
# 414           891.0      52      2           14                   19  ...
# 415          1007.0       8      2            0                    0  ...
# 416            93.0       0      0            0                    0  ...
# 417           480.0      22      1            6                    8  ...
# 418           250.0       0      0            0                    0  ...
# 419           382.0       4      1            0                    0  ...
# 420          1617.0      36      9            0                    0  ...
# 421           720.0      16      4            0                    0  ...
# 422            80.0       0      0            0                    0  ...
# 423          1475.0      20      5            0                    0  ...
# 424            80.0       0      0            0                    0  ...
# 425          1841.0     126     21           18                   24  ...
# 426           972.0      12      3            0                    0  ...
# 427          1593.0      20      5            0                    0  ...
# 428          1121.0      12      3            0                    0  ...
# 429          1113.0      48     12            0                    0  ...
# 430           310.0       4      1            0                    0  ...
# 431          1360.0      16      4            0                    0  ...
# 432          1920.0      20      5            0                    0  ...
# 433           750.0       0      0            0                    0  ...
# 434           650.0       4      1            0                    0  ...
# 435           560.0      12      3            0                    0  ...
# 436            85.0       8      0            3                    4  ...
# 437           895.0       4      1            0                    0  ...
#
#      errors  handling_errors  one_on_ones_lost  penalties  on_report  \
# 0         2                0                 0          1          0
# 1        14               11                 0         27          0
# 2        12                8                 0         11          0
# 3         4                2                 0          6          0
# 4         6                3                 0         15          0
# 5        11                8                 0         19          0
# 6        11                7                 0         17          0
# 7         9                9                 0          9          0
# 8         6                4                 0         15          0
# 9        16               12                 0          8          0
# 10        2                2                 0         10          0
# 11       15                8                 0          5          0
# 12        0                0                 0          0          0
# 13        9                6                 0         15          0
# 14       15               10                 1          0          0
# 15        2                1                 0          7          0
# 16       10                7                 0          0          0
# 17       14               11                 1         33          0
# 18        6                4                 0         14          0
# 19       25               23                 0         26          0
# 20       19                7                 0          1          0
# 21        4                4                 0          2          0
# 22       24               17                 0         21          0
# 23        4                4                 0          2          0
# 24       11                5                 0          7          0
# 25       39               26                 0         16          1
# 26        1                1                 0          1          0
# 27        6                6                 0          2          0
# 28        1                1                 0          3          0
# 29        0                0                 0          4          0
# ..      ...              ...               ...        ...        ...
# 408       4                3                 0         10          0
# 409       3                1                 0          2          0
# 410       1                1                 0          0          0
# 411      32               19                 0          2          0
# 412       3                3                 0          3          0
# 413       2                1                 0          1          0
# 414       6                4                 0          8          0
# 415      10                8                 1         20          0
# 416       1                1                 0          2          0
# 417       2                1                 0          0          0
# 418       4                4                 0          1          0
# 419       2                2                 0          0          0
# 420      18               15                 1         25          0
# 421       9                8                 0          0          0
# 422       1                1                 0          0          0
# 423      13                9                 0         12          0
# 424       1                1                 0          0          0
# 425      24               16                 0          2          0
# 426      11                8                 0         14          1
# 427      19               16                 0         11          0
# 428      12                8                 0          8          0
# 429      19               17                 0          8          0
# 430       0                0                 0          1          0
# 431      21               13                 0          8          1
# 432      18               13                 0          3          0
# 433      10                9                 1         11          0
# 434      12                9                 0          5          0
# 435       4                3                 0          3          0
# 436       3                2                 0          2          0
# 437       7                6                 0         12          1
#
#      sin_bins  send_offs  metres_per_run  metres_per_kick  tackle_percentage
# 0           0          0        6.625000              NaN           0.827586
# 1           1          0        8.774105              NaN           0.932836
# 2           1          0        7.668639              NaN           0.889488
# 3           0          0        8.735632        27.305556           0.860294
# 4           0          0        7.733333              NaN           0.883333
# 5           0          0        5.897260        28.308880           0.838496
# 6           1          0       10.817857        17.000000           0.909244
# 7           0          0        9.671053        15.000000           0.876761
# 8           1          0        8.016949        16.000000           0.895775
# 9           0          0        7.336842        25.847328           0.799427
# 10          0          0        8.104803              NaN           0.936131
# 11          0          0        8.218391              NaN           0.693333
# 12          0          0        9.636364              NaN           0.885714
# 13          0          0        9.178571              NaN           0.850000
# 14          0          0        9.705882        13.750000           0.839695
# 15          1          0        9.840000              NaN           0.951505
# 16          0          0        9.216561        22.394737           0.820789
# 17          0          0        8.062992              NaN           0.928087
# 18          1          0        9.211111        31.258065           0.935450
# 19          0          0        8.423529        21.000000           0.902527
# 20          0          0       10.402390        23.166667           0.696970
# 21          0          0        9.888889        14.000000           0.791667
# 22          1          0        8.007663        31.186380           0.780822
# 23          0          0        9.213592              NaN           0.849057
# 24          1          0        8.637681        21.833333           0.870130
# 25          1          0        6.596491        26.975709           0.795359
# 26          1          0        8.520000              NaN           0.866667
# 27          0          0        7.517241         4.000000           0.753846
# 28          0          0        9.402174              NaN           0.947115
# 29          0          0        8.687500              NaN           0.900000
# ..        ...        ...             ...              ...                ...
# 408         1          0        9.033493        15.000000           0.907131
# 409         0          0        8.000000        10.500000           0.863946
# 410         0          0        0.000000              NaN           1.000000
# 411         0          0        9.953368        14.461538           0.705882
# 412         0          0        8.760000        24.500000           0.773585
# 413         0          0        8.312500              NaN           0.873418
# 414         2          0        5.266667        28.228571           0.765152
# 415         2          0        9.287879              NaN           0.903759
# 416         0          0        9.200000              NaN           0.919355
# 417         0          0        8.972603        21.857143           0.730769
# 418         0          0        8.294118              NaN           0.820896
# 419         1          0        5.955556        18.428571           0.901163
# 420         1          0        8.533113        14.266667           0.827044
# 421         0          0        8.580357              NaN           0.756098
# 422         0          0        6.777778        20.000000           0.714286
# 423         0          0        9.628692        10.000000           0.921788
# 424         0          0        9.166667        26.500000           0.806452
# 425         0          0       10.691824        11.000000           0.664000
# 426         1          0        8.993976              NaN           0.879939
# 427         1          0        9.364217        13.600000           0.819967
# 428         0          0        8.314136        34.119048           0.848635
# 429         0          0       10.435115         6.000000           0.840426
# 430         0          0        6.791667         3.500000           0.935000
# 431         0          0        9.058511        20.600000           0.796774
# 432         0          0        8.941995        14.333333           0.801948
# 433         1          0        6.693548              NaN           0.880109
# 434         0          0        8.578947        23.000000           0.865455
# 435         0          0        9.542857        10.000000           0.787879
# 436         0          0        6.222222              NaN           0.840000
# 437         0          0        9.837607              NaN           0.912966
#
# [438 rows x 54 columns]

# %% [markdown]
# # Rank players on important stats..group by position

# %% [markdown]
# ### Team of the Year:
# <br>
#     Fullback --> Roger Tuivasa-Sheck (Warriors)
#     <br>
#     Winger --> Blake Ferguson (Roosters)
#     <br>
#     Centre --> Joseph Leilua (Raiders)
#     <br>
#     Five-eighth --> Cameron Munster (Storm)
#     <br>
#     Halfback --> Luke Brooks (Tigers)
#     <br>
#     Lock --> Jason Taumalolo (Cowboys)
#     <br>
#     Second-rower --> Josh Jackson (Bulldogs)
#     <br>
#     Prop --> Andrew Fifita (Sharks)
#     <br>
#     Hooker --> Damien Cook (Rabbitohs)
#     <br>
#     Interchange --> Jazz Tevaga (Warriors)

# %%
player_stats_with_positions = player_stats_with_positions[player_stats_with_positions['minutes_played'] > 800]
#stats_positions_merged.shape
main_stats = ['name', 'main_position', 'minutes_played', 'tries', 'try_assists', 'total_run_metres', 'total_runs', 'metres_per_run', 'kicks', 'kicking_metres', 'metres_per_kick', 'tackles_made', 'tackle_percentage']

df_by_position = {}

for i in range(11):
    if i > 0:
        important_stats = player_stats_with_positions[main_stats]
        position_df = important_stats[important_stats['main_position'] == i]
        df_by_position[i] = position_df.sort_values(['total_run_metres', 'tries', 'metres_per_kick', 'total_runs', 'tackle_percentage'], ascending = [0,0,0,0, 0])
        #stat_leader_df.append(df_by_position[i].sort_values(['total_run_metres', 'tries', 'metres_per_kick', 'total_runs', 'tackle_percentage'], ascending = [0,0,0,0, 0])[:5])

        
stat_leader_df = pd.DataFrame()      
for key in df_by_position:
    stat_leader_df = pd.concat([stat_leader_df, df_by_position[key][:5]])
stat_leader_df
# Out:
#                     name  main_position  minutes_played  tries  try_assists  \
# 174        James Tedesco              1          1748.0      9           11
# 354  Roger Tuivasa-sheck              1          1743.0      3            8
# 411        Tom Trbojevic              1          1712.0      9           14
# 425     Valentine Holmes              1          1841.0     21            8
# 292        Matthew Dufty              1          1893.0     12            8
# 37        Blake Ferguson              2          1918.0     17            4
# 128      George Jennings              2          2746.0     15            0
# 237          Ken Maumalo              2          1760.0      5            0
# 80           Corey Oates              2          1702.0     18            2
# 254           Kyle Feldt              2          1920.0     14            2
# 432         Will Hopoate              3          1920.0      5            7
# 114        Esan Marsters              3          1928.0      3            7
# 116          Euan Aitken              3          1765.0     10            1
# 350        Ricky Leutele              3          1727.0      3            5
# 90            Dane Gagai              3          1759.0      3           10
# 420       Tyrone Peachey              4          1617.0      9            6
# 58       Cameron Munster              4          1671.0      5           15
# 22       Anthony Milford              4          1918.0      6           12
# 79          Corey Norman              4          1823.0      4           12
# 36          Blake Austin              4          1576.0      5            7
# 272          Luke Brooks              5          1918.0      5           10
# 88     Daly Cherry-Evans              5          1930.0      8           15
# 246        Kodi Nikorima              5          1727.0      9            9
# 200   Johnathan Thurston              5          1920.0      3           23
# 379        Shaun Johnson              5          1430.0      4           14
# 101        David Klemmer              6          1244.0      0            0
# 284        Martin Taupau              6          1222.0      0            1
# 294        Matthew Lodge              6          1128.0      3            1
# 1            Aaron Woods              6          1227.0      1            0
# 17         Andrew Fifita              6          1316.0      3            2
# 89           Damien Cook              7          1736.0      4            8
# 140           Issac Luke              7          1559.0      5            2
# 57       Cameron McInnes              7          1860.0      3            6
# 382        Siliva Havili              7          1052.0      3            2
# 384          Sione Katoa              7          1635.0      3            5
# 427        Viliame Kikau              8          1593.0      5            1
# 19        Angus Crichton              8          1744.0      3            1
# 199          John Sutton              8          1842.0      4            5
# 138            Isaah Yeo              8          1757.0      3            2
# 395           Tariq Sims              8          1770.0      7            2
# 183      Jason Taumalolo              9          1430.0      4            1
# 164       Jake Trbojevic              9          1801.0      7            3
# 158            Jai Arrow              9          1146.0      3            0
# 361          Sam Burgess              9          1402.0      1            2
# 223         Josh Papalii              9          1480.0      5            2
# 194       Joe Ofahengaue             10          1160.0      3            0
# 262        Leeson Ah Mau             10           902.0      1            0
# 437        Zane Tetevano             10           895.0      1            0
# 173          James Tamou             10           936.0      2            0
# 299     Michael Chee-Kam             10          1270.0      3            1
#
#      total_run_metres  total_runs  metres_per_run  kicks  kicking_metres  \
# 174              4202         377       11.145889      6              86
# 354              4045         391       10.345269      2              22
# 411              3842         386        9.953368     26             376
# 425              3400         318       10.691824     11             121
# 292              3071         297       10.340067      4              69
# 37               4880         486       10.041152      5              73
# 128              4192         469        8.938166      1              19
# 237              3364         353        9.529745      3              52
# 80               3225         279       11.559140      3              59
# 254              3098         328        9.445122      3              58
# 432              3854         431        8.941995      6              86
# 114              3103         336        9.235119      9             102
# 116              2628         294        8.938776      1               3
# 350              2598         280        9.278571     14             287
# 90               2546         281        9.060498      7             117
# 420              2577         302        8.533113     15             214
# 58               2121         266        7.973684    109            2411
# 22               2090         261        8.007663    279            8701
# 79               1971         242        8.144628    176            4655
# 36               1794         195        9.200000     78            2141
# 272              1988         244        8.147541    210            5434
# 88               1550         202        7.673267    243            6218
# 246              1548         157        9.859873     90            2384
# 200              1506         254        5.929134    211            4445
# 379              1304         164        7.951220    151            4112
# 101              3974         408        9.740196      2              32
# 284              3752         371       10.113208      3              32
# 294              3231         346        9.338150      0               0
# 1                3185         363        8.774105      0               0
# 17               3072         381        8.062992      0               0
# 89               2307         229       10.074236     12             304
# 140              1637         166        9.861446     30            1134
# 57               1509         153        9.862745     13             136
# 382              1271         124       10.250000     10             258
# 384              1180         137        8.613139     20             557
# 427              2931         313        9.364217      5              68
# 19               2864         340        8.423529      3              63
# 199              2755         301        9.152824      7              61
# 138              2694         283        9.519435      4              67
# 395              2462         275        8.952727      2              54
# 183              4104         408       10.058824      1               2
# 164              3133         373        8.399464      3              66
# 158              2974         324        9.179012      0               0
# 361              2930         332        8.825301      3              74
# 223              2888         310        9.316129      0               0
# 194              2876         309        9.307443      1              10
# 262              2567         253       10.146245      1              20
# 437              2302         234        9.837607      0               0
# 173              2164         219        9.881279      0               0
# 299              2110         239        8.828452      3              35
#
#      metres_per_kick  tackles_made  tackle_percentage
# 174        14.333333           114           0.802817
# 354        11.000000            66           0.600000
# 411        14.461538            96           0.705882
# 425        11.000000            83           0.664000
# 292        17.250000           102           0.713287
# 37         14.600000            81           0.764151
# 128        19.000000           243           0.826531
# 237        17.333333            69           0.726316
# 80         19.666667            75           0.669643
# 254        19.333333           139           0.827381
# 432        14.333333           247           0.801948
# 114        11.333333           322           0.827763
# 116         3.000000           360           0.841121
# 350        20.500000           234           0.844765
# 90         16.714286           344           0.785388
# 420        14.266667           263           0.827044
# 58         22.119266           399           0.819302
# 22         31.186380           285           0.780822
# 79         26.448864           350           0.784753
# 36         27.448718           301           0.798408
# 272        25.876190           361           0.729293
# 88         25.588477           442           0.838710
# 246        26.488889           404           0.819473
# 200        21.066351           327           0.743182
# 379        27.231788           315           0.793451
# 101        16.000000           542           0.923339
# 284        10.666667           671           0.912925
# 294              NaN           547           0.887987
# 1                NaN           625           0.932836
# 17               NaN           684           0.928087
# 89         25.333333           944           0.910318
# 140        37.800000           681           0.869732
# 57         10.461538          1062           0.936508
# 382        25.800000           574           0.905363
# 384        27.850000           561           0.894737
# 427        13.600000           501           0.819967
# 19         21.000000           750           0.902527
# 199         8.714286           598           0.904690
# 138        16.750000           727           0.924936
# 395        27.000000           600           0.874636
# 183         2.000000           635           0.873453
# 164        22.000000           967           0.937016
# 158              NaN           635           0.899433
# 361        24.666667           634           0.868493
# 223              NaN           644           0.900699
# 194        10.000000           648           0.923077
# 262        20.000000           539           0.945614
# 437              NaN           514           0.912966
# 173              NaN           620           0.930931
# 299        11.666667           558           0.855828

# %%
#1 --> compare Tedesco to Tuivasa-Sheck
#3 --> Leilua isn't in there
#4 --> Peachey vs. Munster vs. Milford
#6 --> Klemmer vs. Tapau vs. Lodge vs. Woods vs. Fifita
#8 --> Jackson isn't in there
#10 --> Jazz isn't in there

# %% [markdown]
# # Based off of position stats, make graphs compairing positions where there wasn't a clear 'best player'...or...the 'best player' should have been someone else

# %%
#First...We'll look at Centres and Second Rowers to see why Leilua and Jackson are in the team despite not being top in their positions

#Second...Well do deeper analysis into Tedesco vs. Tuivasa-Sheck...did Tuivasa-Sheck prevail because he played for a crappier team?
#These positions are running heavy so we'll focus on running stats

#Third...Same with Peachey / Munster / Milford...these positions require a bit of everything so we'll look at all stats

# %% [markdown]
# ### Centres

# %%
center_df = player_stats_with_positions[player_stats_with_positions['main_position'] == 3]
center_df = center_df[center_df['minutes_played'] > 800]
center_df = center_df.sort_values(['total_run_metres', 'tries', 'metres_per_kick', 'total_runs', 'tackle_percentage'], ascending = [0,0,0,0, 0])
center_df = center_df.set_index('name').head(10)
center_df.drop(columns=['id', 'player_id', 'team_id', 'main_position'])
# Out:
#                minutes_played  points  tries  conversions  \
# name
# Will Hopoate           1920.0      20      5            0
# Esan Marsters          1928.0     124      3           36
# Euan Aitken            1765.0      40     10            0
# Ricky Leutele          1727.0      12      3            0
# Dane Gagai             1759.0      12      3            0
# Timoteo Lafai          1920.0      28      5            3
# Joseph Leilua          1741.0      56     14            0
# Peta Hiku              1518.0      16      4            0
# Brian Kelly            1922.0      28      7            0
# Solomone Kata          1716.0      48     12            0
#
#                conversion_attempts  penalty_goals  field_goals  total_runs  \
# name
# Will Hopoate                     0              0            0         431
# Esan Marsters                   53             20            0         336
# Euan Aitken                      0              0            0         294
# Ricky Leutele                    0              0            0         280
# Dane Gagai                       1              0            0         281
# Timoteo Lafai                    3              0            0         280
# Joseph Leilua                    0              0            0         262
# Peta Hiku                        0              0            0         260
# Brian Kelly                      0              0            0         249
# Solomone Kata                    1              0            0         227
#
#                total_run_metres  kick_return_metres  ...  errors  \
# name                                                 ...
# Will Hopoate               3854                 651  ...      18
# Esan Marsters              3103                  40  ...      23
# Euan Aitken                2628                  39  ...      11
# Ricky Leutele              2598                  10  ...      14
# Dane Gagai                 2546                 258  ...      23
# Timoteo Lafai              2495                  31  ...      28
# Joseph Leilua              2481                  23  ...      21
# Peta Hiku                  2346                 154  ...      12
# Brian Kelly                2279                  77  ...      22
# Solomone Kata              2258                  60  ...      16
#
#                handling_errors  one_on_ones_lost  penalties  on_report  \
# name
# Will Hopoate                13                 0          3          0
# Esan Marsters               17                 1         12          0
# Euan Aitken                 11                 0          7          0
# Ricky Leutele               13                 0          6          0
# Dane Gagai                  15                 1          4          0
# Timoteo Lafai               21                 0         13          0
# Joseph Leilua               17                 0         17          0
# Peta Hiku                   10                 1         11          0
# Brian Kelly                 15                 1         11          0
# Solomone Kata               11                 1         16          0
#
#                sin_bins  send_offs  metres_per_run  metres_per_kick  \
# name
# Will Hopoate          0          0        8.941995        14.333333
# Esan Marsters         0          0        9.235119        11.333333
# Euan Aitken           0          0        8.938776         3.000000
# Ricky Leutele         0          0        9.278571        20.500000
# Dane Gagai            0          0        9.060498        16.714286
# Timoteo Lafai         0          0        8.910714        15.500000
# Joseph Leilua         1          0        9.469466        12.000000
# Peta Hiku             1          0        9.023077         8.500000
# Brian Kelly           0          0        9.152610        10.500000
# Solomone Kata         1          0        9.947137         3.000000
#
#                tackle_percentage
# name
# Will Hopoate            0.801948
# Esan Marsters           0.827763
# Euan Aitken             0.841121
# Ricky Leutele           0.844765
# Dane Gagai              0.785388
# Timoteo Lafai           0.828313
# Joseph Leilua           0.776173
# Peta Hiku               0.771588
# Brian Kelly             0.737245
# Solomone Kata           0.885350
#
# [10 rows x 49 columns]

# %% [markdown]
# # Second Row

# %%
sr_df = player_stats_with_positions[player_stats_with_positions['main_position'] == 6]
sr_df = sr_df[sr_df['minutes_played'] > 800]
sr_df = sr_df.sort_values(['total_run_metres', 'tries', 'metres_per_kick', 'total_runs', 'tackle_percentage'], ascending = [0,0,0,0,0])
sr_df = sr_df.set_index('name').head(10)
sr_df.drop(columns=['id', 'player_id', 'team_id', 'main_position'])
# Out:
#                    minutes_played  points  tries  conversions  \
# name
# David Klemmer              1244.0       0      0            0
# Martin Taupau              1222.0       0      0            0
# Matthew Lodge              1128.0      12      3            0
# Aaron Woods                1227.0       4      1            0
# Andrew Fifita              1316.0      12      3            0
# Addin Fonua-blake          1152.0      12      3            0
# Siosiua Taukeiaho           978.0      14      1            2
# Herman Ese'ese             1209.0       8      2            0
# Thomas Burgess             1072.0      20      5            0
# Ryan James                 1659.0      24      6            0
#
#                    conversion_attempts  penalty_goals  field_goals  \
# name
# David Klemmer                        0              0            0
# Martin Taupau                        0              0            0
# Matthew Lodge                        0              0            0
# Aaron Woods                          0              0            0
# Andrew Fifita                        0              0            0
# Addin Fonua-blake                    0              0            0
# Siosiua Taukeiaho                    4              3            0
# Herman Ese'ese                       0              0            0
# Thomas Burgess                       0              0            0
# Ryan James                           0              0            0
#
#                    total_runs  total_run_metres  kick_return_metres  ...  \
# name                                                                 ...
# David Klemmer             408              3974                 467  ...
# Martin Taupau             371              3752                 611  ...
# Matthew Lodge             346              3231                 907  ...
# Aaron Woods               363              3185                 175  ...
# Andrew Fifita             381              3072                 410  ...
# Addin Fonua-blake         280              3029                 616  ...
# Siosiua Taukeiaho         277              2988                 506  ...
# Herman Ese'ese            319              2833                 406  ...
# Thomas Burgess            276              2731                 491  ...
# Ryan James                319              2695                 138  ...
#
#                    errors  handling_errors  one_on_ones_lost  penalties  \
# name
# David Klemmer           7                4                 0         11
# Martin Taupau          14               10                 0         17
# Matthew Lodge          11               10                 0         12
# Aaron Woods            14               11                 0         27
# Andrew Fifita          14               11                 1         33
# Addin Fonua-blake      11                7                 0         17
# Siosiua Taukeiaho      10               10                 0          3
# Herman Ese'ese          7                5                 0         10
# Thomas Burgess          9                8                 1          9
# Ryan James              9                5                 0         25
#
#                    on_report  sin_bins  send_offs  metres_per_run  \
# name
# David Klemmer              0         1          0        9.740196
# Martin Taupau              0         0          0       10.113208
# Matthew Lodge              1         0          0        9.338150
# Aaron Woods                0         1          0        8.774105
# Andrew Fifita              0         0          0        8.062992
# Addin Fonua-blake          0         1          0       10.817857
# Siosiua Taukeiaho          0         0          0       10.787004
# Herman Ese'ese             0         0          0        8.880878
# Thomas Burgess             1         1          0        9.894928
# Ryan James                 0         0          0        8.448276
#
#                    metres_per_kick  tackle_percentage
# name
# David Klemmer            16.000000           0.923339
# Martin Taupau            10.666667           0.912925
# Matthew Lodge                  NaN           0.887987
# Aaron Woods                    NaN           0.932836
# Andrew Fifita                  NaN           0.928087
# Addin Fonua-blake        17.000000           0.909244
# Siosiua Taukeiaho         9.000000           0.904587
# Herman Ese'ese            1.000000           0.925546
# Thomas Burgess                 NaN           0.881271
# Ryan James               15.000000           0.893167
#
# [10 rows x 49 columns]

# %% [markdown]
# # Rank players based on how big an impact they had for their respective teams

# %% [markdown]
# The below formuala takes in a dictionary of players and their respective teams and returns a dataframe comparing a players' impacts on their teams overall statistical output

# %%
def compare_individual_contribution_to_team(player_dict):
    def find_team_stats(team_name, stat):
        stats = team_stats.loc[team_name]
        return stats[stat]
    
    individual_impact = {}

    for name, team in player_dict.items():
        individual_impact[name] = {}
        individual_impact[name]['name'] = name
        player_df = stat_leader_df[stat_leader_df['name'] == name]
        player_df = player_df[['name', 'tries', 'try_assists', 'total_run_metres', 'total_runs', 'kicks', 'kicking_metres', 'tackles_made']]
        i = 0
        while i < len(player_df.columns):
            try:
                combined_team_stat = find_team_stats(team, player_df.columns[i])
                percent_of_team_stat = player_df[player_df.columns[i]] / combined_team_stat
                individual_impact[name][player_df.columns[i]] = (percent_of_team_stat.item() * 100)
                i += 1
            except:
                i += 1
                continue

    comparison_dataframe = pd.DataFrame()
    for i in individual_impact:
        player_dataframe = pd.DataFrame([individual_impact[i]], columns=individual_impact[i].keys())
        comparison_dataframe = pd.concat([comparison_dataframe, player_dataframe])
    return comparison_dataframe.set_index('name').round(2)

# %% [markdown]
# # Fullbacks

# %%
stat_leader_df.set_index('name').loc[['James Tedesco', 'Roger Tuivasa-sheck']]
# Out:
#                      main_position  minutes_played  tries  try_assists  \
# name
# James Tedesco                    1          1748.0      9           11
# Roger Tuivasa-sheck              1          1743.0      3            8
#
#                      total_run_metres  total_runs  metres_per_run  kicks  \
# name
# James Tedesco                    4202         377       11.145889      6
# Roger Tuivasa-sheck              4045         391       10.345269      2
#
#                      kicking_metres  metres_per_kick  tackles_made  \
# name
# James Tedesco                    86        14.333333           114
# Roger Tuivasa-sheck              22        11.000000            66
#
#                      tackle_percentage
# name
# James Tedesco                 0.802817
# Roger Tuivasa-sheck           0.600000

# %%
fullbacks = {'James Tedesco': 'Roosters', 'Roger Tuivasa-sheck': 'Warriors'}
compare_individual_contribution_to_team(fullbacks)
# Out:
#                      tries  try_assists  total_run_metres  total_runs  kicks  \
# name
# James Tedesco        10.23        14.67             11.04        9.46   1.35
# Roger Tuivasa-sheck   3.75        12.70             10.95        9.69   0.48
#
#                      kicking_metres  tackles_made
# name
# James Tedesco                  0.76          1.44
# Roger Tuivasa-sheck            0.20          0.84

# %% [markdown]
# # Five-Eighths

# %%
stat_leader_df.set_index('name').loc[['Tyrone Peachey', 'Cameron Munster', 'Anthony Milford']]
# Out:
#                  main_position  minutes_played  tries  try_assists  \
# name
# Tyrone Peachey               4          1617.0      9            6
# Cameron Munster              4          1671.0      5           15
# Anthony Milford              4          1918.0      6           12
#
#                  total_run_metres  total_runs  metres_per_run  kicks  \
# name
# Tyrone Peachey               2577         302        8.533113     15
# Cameron Munster              2121         266        7.973684    109
# Anthony Milford              2090         261        8.007663    279
#
#                  kicking_metres  metres_per_kick  tackles_made  \
# name
# Tyrone Peachey              214        14.266667           263
# Cameron Munster            2411        22.119266           399
# Anthony Milford            8701        31.186380           285
#
#                  tackle_percentage
# name
# Tyrone Peachey            0.827044
# Cameron Munster           0.819302
# Anthony Milford           0.780822

# %%
five_eights = {'Tyrone Peachey': 'Panthers', 'Cameron Munster': 'Storm', 'Anthony Milford': 'Broncos'}
compare_individual_contribution_to_team(five_eights)
# Out:
#                  tries  try_assists  total_run_metres  total_runs  kicks  \
# name
# Tyrone Peachey   10.98         9.84              7.00        7.35   3.62
# Cameron Munster   5.62        25.00              6.01        6.71  25.53
# Anthony Milford   6.82        20.69              5.84        6.66  60.78
#
#                  kicking_metres  tackles_made
# name
# Tyrone Peachey             2.09          3.45
# Cameron Munster           23.01          5.16
# Anthony Milford           66.57          3.68
