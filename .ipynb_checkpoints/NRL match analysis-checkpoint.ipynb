# %% [markdown]
# # NRL Team of the Year Analysis

# %% [markdown]
# Going to first determine which stats are most important to a teams win / loss record. Then we'll determine which players had the biggest impact on their team's success. Compare this to the 2018 Team of the Year to see if it's a fair reflection of the statistical data

# %% [markdown]
# ### Team of the Year:
# <br>
#     Fullback --> Roger Tuivasa-Sheck (Warriors)
#     <br>
#     Winger --> Blake Ferguson (Roosters)
#     <br>
#     Centre --> Joseph Leilua (Raiders)
#     <br>
#     Five-eighth --> Cameron Munster (Storm)
#     <br>
#     Halfback --> Luke Brooks (Tigers)
#     <br>
#     Lock --> Jason Taumalolo (Cowboys)
#     <br>
#     Second-rower --> Josh Jackson (Bulldogs)
#     <br>
#     Prop --> Andrew Fifita (Sharks)
#     <br>
#     Hooker --> Damien Cook (Rabbitohs)
#     <br>
#     Interchange --> Jazz Tevaga (Warriors)

# %%
#Import Pandas and connect to database
import pandas as pd
import mysql.connector as sql

mydb = sql.connect(
  host="localhost",
  user="root",
  passwd="NYg1@nts",
  database="NRL_data"
)

# %%
#Function to easily create dataframes from SQL query results
def create_df(query):
    return pd.read_sql_query(query, con=mydb)

# %% [markdown]
# # Make Standings to have better idea of teams that performed well

# %%
#Only want to view matches from 2018
#Want to create standings to have an idea of teams that performed well vs. poorly
match_query = '''SELECT m.id, m.round, m.date,
CASE
	WHEN m.home_team_id = m.winner THEN home.nickname
    ELSE away.nickname
END winner,
CASE
	WHEN m.home_team_id = m.winner THEN m.home_score
    ELSE m.away_score
END winning_score,
CASE
	WHEN m.home_team_id = m.winner THEN away.nickname
    ELSE home.nickname
END loser,
CASE
	WHEN m.home_team_id = m.winner THEN m.away_score
    ELSE m.home_score
END losing_score, home.nickname home, away.nickname away
FROM Matches m
JOIN Teams home
ON m.home_team_id = home.id
JOIN Teams away
ON m.away_team_id = away.id
WHERE year(m.date) = 2018
ORDER BY date;'''
matches_df = create_df(match_query)
matches_df.head()
# Out:
#    id  round        date    winner  winning_score       loser  losing_score  \
# 0   1      1  2018-03-08   Dragons             34     Broncos            12
# 1   2      1  2018-03-09   Knights             19  Sea Eagles            18
# 2   3      1  2018-03-09   Cowboys             20      Sharks            14
# 3   6      1  2018-03-10     Storm             36    Bulldogs            18
# 4   5      1  2018-03-10  Warriors             32   Rabbitohs            20
#
#         home        away
# 0    Dragons     Broncos
# 1    Knights  Sea Eagles
# 2    Cowboys      Sharks
# 3   Bulldogs       Storm
# 4  Rabbitohs    Warriors

# %%
winners = matches_df.groupby('winner')
w_scored = winners['winning_score'].sum()
w_allowed = winners['losing_score'].sum()

losers = matches_df.groupby('loser')
l_scored = losers['losing_score'].sum()
l_allowed = losers['winning_score'].sum()

total_scores = pd.concat([w_scored, l_scored, w_allowed, l_allowed], axis=1, join='inner')
total_scores.columns = ['scored_in_win', 'scored_in_loss', 'allowed_in_win', 'allowed_in_loss']
total_scores.head(2)

total_scores['pts_scored'] = total_scores['scored_in_win'] + total_scores['scored_in_loss']
total_scores['pts_allowed'] = total_scores['allowed_in_win'] + total_scores['allowed_in_loss']
total_scores['pts_differential'] = total_scores['pts_scored'] - total_scores['pts_allowed']
total_points_data = total_scores[['pts_differential', 'pts_scored', 'pts_allowed']]
total_points_data.head()
# Out:
#           pts_differential  pts_scored  pts_allowed
# Broncos                 56         556          500
# Bulldogs               -46         428          474
# Cowboys                -72         449          521
# Dragons                 47         519          472
# Eels                  -176         374          550

# %%
#Pull win / loss records from database
win_loss_query = '''SELECT t.nickname team,
    count(m.winner) as wins,
    24 - count(m.winner) as loses
FROM Matches m
JOIN Teams t
ON m.winner = t.id
WHERE year(m.date) = 2018
GROUP BY m.winner
ORDER BY wins DESC;'''
win_loss_df = create_df(win_loss_query).set_index('team')
win_loss_df.head()
# Out:
#            wins  loses
# team
# Roosters     16      8
# Rabbitohs    16      8
# Storm        16      8
# Sharks       16      8
# Dragons      15      9

# %%
final_standings = pd.concat([win_loss_df, total_points_data], axis=1, join='inner').sort_values(['wins', 'pts_differential'], ascending=[0,0])
final_standings
# Out:
#             wins  loses  pts_differential  pts_scored  pts_allowed
# Roosters      16      8               181         542          361
# Storm         16      8               173         536          363
# Rabbitohs     16      8               145         582          437
# Sharks        16      8                96         519          423
# Broncos       15      9                56         556          500
# Panthers      15      9                56         517          461
# Dragons       15      9                47         519          472
# Warriors      15      9                25         472          447
# Tigers        12     12               -83         377          460
# Raiders       10     14                23         563          540
# Knights        9     15              -193         414          607
# Bulldogs       8     16               -46         428          474
# Cowboys        8     16               -72         449          521
# Titans         8     16              -110         472          582
# Sea Eagles     7     17              -122         500          622
# Eels           6     18              -176         374          550

# %%
final_standings.plot.scatter(x='wins', y='pts_differential', color='Red', label='point_differential')
final_standings.plot.scatter(x='wins', y='pts_scored', color='Blue', label='scored')
final_standings.plot.scatter(x='wins', y='pts_allowed', color='Green', label='allowed')

# %% [markdown]
# We can see correlation between point_differential and wins, but lets look at alternative metrics and player stats to find a better correlation to win probability.

# %% [markdown]
# # Want to see if there are any statistics that are a good predictor of wins

# %%
#PlayerMatchStats
query = '''SELECT CONCAT(p.first_name, ' ' ,p.last_name) name, t.nickname team, p_stats.*
        FROM PlayerMatchStats p_stats
        JOIN Players p
        ON p_stats.player_id = p.id
        JOIN Teams t
        ON p_stats.team_id = t.id
        JOIN Matches m
        ON p_stats.match_id = m.id
        WHERE year(m.date) = 2018;'''

player_stat_df = create_df(query)
player_stat_df.head()
# Out:
#              name     team  id  match_id  player_id  team_id  position_id  \
# 0     Darius Boyd  Broncos  18         1         22        1            1
# 1     Corey Oates  Broncos  19         1         20        1            2
# 2   James Roberts  Broncos  20         1         27        1            3
# 3     Jordan Kahu  Broncos  21         1        251        1            3
# 4  Jamayne Isaako  Broncos  22         1         26        1            2
#
#    minutes_played  points  tries  ...  kicked_dead  errors  handling_errors  \
# 0            80.0       0      0  ...            0       1                1
# 1            80.0       0      0  ...            0       1                1
# 2            80.0       8      2  ...            0       0                0
# 3            80.0       4      0  ...            0       1                1
# 4            80.0       0      0  ...            0       2                0
#
#   one_on_ones_lost  penalties  on_report  sin_bins  send_offs  stint_one  \
# 0                0          0          0         0          0       80.0
# 1                0          0          0         0          0       80.0
# 2                0          1          0         0          0       80.0
# 3                0          0          0         0          0       80.0
# 4                0          0          0         0          0       80.0
#
#    stint_two
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#
# [5 rows x 58 columns]

# %%
#Look at columns...what can we drop and what can we alter?
player_stat_df.columns
# Out:
# Index(['name', 'team', 'id', 'match_id', 'player_id', 'team_id', 'position_id',
#        'minutes_played', 'points', 'tries', 'conversions',
#        'conversion_attempts', 'penalty_goals', 'conversion_percentage',
#        'field_goals', 'total_runs', 'total_run_metres', 'kick_return_metres',
#        'post_contact_metres', 'line_breaks', 'line_break_assists',
#        'try_assists', 'line_engaged_runs', 'tackle_breaks', 'hit_ups',
#        'play_the_ball', 'average_play_ball_seconds', 'dummy_half_runs',
#        'dummy_half_run_metres', 'steals', 'offloads', 'dummy_passes', 'passes',
#        'receipts', 'pass_to_run_ratio', 'tackle_percentage', 'tackles_made',
#        'tackles_missed', 'ineffective_tackles', 'intercepts', 'kicks_defused',
#        'kicks', 'kicking_metres', 'forced_drop_outs', 'bomb_kicks', 'grubbers',
#        'fourty_twenty', 'cross_field_kicks', 'kicked_dead', 'errors',
#        'handling_errors', 'one_on_ones_lost', 'penalties', 'on_report',
#        'sin_bins', 'send_offs', 'stint_one', 'stint_two'],
#       dtype='object')

# %%
player_stat_df = player_stat_df.drop(['id', 'team_id', 'conversions', 'conversion_attempts', 'penalty_goals', 'conversion_percentage',
                           'field_goals', 'hit_ups', 'play_the_ball', 'average_play_ball_seconds', 'dummy_half_runs',
                           'dummy_half_run_metres', 'steals', 'dummy_passes', 'receipts', 'pass_to_run_ratio',
                           'intercepts', 'kicks_defused', 'forced_drop_outs', 'bomb_kicks', 'grubbers', 'fourty_twenty',
                           'cross_field_kicks', 'kicked_dead', 'handling_errors', 'one_on_ones_lost', 'on_report',
                           'send_offs', 'stint_one', 'stint_two'], axis=1)

# %%
player_stats_grouped = player_stat_df.groupby('name').agg(sum)
player_stats_grouped
# Out:
#                        match_id  player_id  position_id  minutes_played  \
# name
# Aaron Gray                    9         87            3            80.0
# Aaron Woods                2197       2346          174          1227.0
# Adam Blair                 2047       4840          185          1390.0
# Adam Doueihi               1527       6192          134           674.0
# Adam Elliott               2323       1464          217          1063.0
# Adam Reynolds              2221       7245          105          1670.0
# Addin Fonua-blake          2315      12216          144          1152.0
# Agnatius Paasi             2299       4862          135           868.0
# Aidan Guerra               2298       4512          203          1674.0
# Aidan Sezer                1351        594           96          1380.0
# Aiden Tolman               1811        992          114           889.0
# Akuila Uate                 908       7620           30          1209.0
# Albert Vete                 233        471           30            64.0
# Alex Glenn                 1913         40          161          1467.0
# Alex Johnston              1921       7266           21          1539.0
# Alex Twal                  1941       9219          206           770.0
# Alexander Brimson          2006       1665           48          1179.0
# Andrew Fifita              2217       2369          138          1316.0
# Andrew McCullough          1936         63          150          1528.0
# Angus Crichton             2081      11638          176          1744.0
# Anthony Don                2350       2688           48          1924.0
# Anthony Gelling             469       4095           48           268.0
# Anthony Milford            2315        456           97          1918.0
# Antonio Winterstein        1030       8272           32          1268.0
# Apisai Koroisau             705       1989           91           910.0
# Ashley Taylor              2338       2599          115          1778.0
# Asipeli Fine                286       2976           60           114.0
# Ata Hingano                 649        350          100           237.0
# Ava Seumanufagai            687       1352          125           340.0
# Beau Scott                  304       3864           67           219.0
# ...                         ...        ...          ...             ...
# Tohu Harris                1211       3744          128          1204.0
# Tom Opacic                  708       3108           78           508.0
# Tom Starling                188        630           10            17.0
# Tom Trbojevic              2179       3322           22          1712.0
# Tom Wright                  467       2460           28           165.0
# Tony Williams               237       2935           42           258.0
# Trent Hodkinson            2022       2736          132           891.0
# Trent Merrin               2251      12558          162          1007.0
# Tui Kamikamica              744        860           50            93.0
# Tuimoala Lolohea            374       3126            6           480.0
# Tyrell Fuimaono             725       2046           53           250.0
# Tyrone May                 1264       2600           62           382.0
# Tyrone Peachey             2063       2640           87          1617.0
# Tyrone Phillips             903       5508           18           720.0
# Tyronne Roberts-davis        54        604            2            80.0
# Tyson Frizell              1954       8547          162          1475.0
# Tyson Gamble                116        470            4            80.0
# Valentine Holmes           2214      10856           30          1841.0
# Victor Radley              2093       9306          206           972.0
# Viliame Kikau              2207       7866          196          1593.0
# Wade Graham                1589       8092          136          1121.0
# Waqa Blake                 1506       4564           42          1113.0
# Wayde Egan                 1238       6960          117           310.0
# Will Chambers              1519       3179           51          1360.0
# Will Hopoate               2323       2016           52          1920.0
# Will Matthews              1443       8370          133           750.0
# Will Smith                  926       3731          109           650.0
# Young Tonumaipea            591       4123           18           560.0
# Zac Lomax                   267        778           13            85.0
# Zane Tetevano              2305      10176          232           895.0
#
#                        points  tries  total_runs  total_run_metres  \
# name
# Aaron Gray                  0      0           8                53
# Aaron Woods                 4      1         363              3185
# Adam Blair                  4      1         169              1296
# Adam Doueihi               26      2          87               760
# Adam Elliott               16      4         240              1856
# Adam Reynolds             186      4         146               861
# Addin Fonua-blake          12      3         280              3029
# Agnatius Paasi             12      3         228              2205
# Aidan Guerra               20      5         295              2365
# Aidan Sezer                21      2          95               697
# Aiden Tolman                0      0         229              1856
# Akuila Uate                20      5         174              1430
# Albert Vete                 0      0          22               212
# Alex Glenn                 16      4         196              1799
# Alex Johnston              32      8         204              1980
# Alex Twal                   0      0         200              1968
# Alexander Brimson          28      7         157              1447
# Andrew Fifita              12      3         381              3072
# Andrew McCullough          12      3          90               829
# Angus Crichton             12      3         340              2864
# Anthony Don                60     15         251              2611
# Anthony Gelling             8      2          45               445
# Anthony Milford            25      6         261              2090
# Antonio Winterstein        28      7         206              1898
# Apisai Koroisau            12      3          69               596
# Ashley Taylor              52      3         171              1128
# Asipeli Fine                0      0          25               213
# Ata Hingano                 0      0          29               218
# Ava Seumanufagai            0      0          92               865
# Beau Scott                  0      0          32               278
# ...                       ...    ...         ...               ...
# Tohu Harris                 8      2         209              1888
# Tom Opacic                  4      1          75               600
# Tom Starling                0      0           1                 0
# Tom Trbojevic              36      9         386              3842
# Tom Wright                  4      1          25               219
# Tony Williams               0      0          48               399
# Trent Hodkinson            52      2          45               237
# Trent Merrin                8      2         264              2452
# Tui Kamikamica              0      0          25               230
# Tuimoala Lolohea           22      1          73               655
# Tyrell Fuimaono             0      0          34               282
# Tyrone May                  4      1          45               268
# Tyrone Peachey             36      9         302              2577
# Tyrone Phillips            16      4         112               961
# Tyronne Roberts-davis       0      0           9                61
# Tyson Frizell              20      5         237              2282
# Tyson Gamble                0      0           6                55
# Valentine Holmes          126     21         318              3400
# Victor Radley              12      3         166              1493
# Viliame Kikau              20      5         313              2931
# Wade Graham                12      3         191              1588
# Waqa Blake                 48     12         131              1367
# Wayde Egan                  4      1          24               163
# Will Chambers              16      4         188              1703
# Will Hopoate               20      5         431              3854
# Will Matthews               0      0          62               415
# Will Smith                  4      1          76               652
# Young Tonumaipea           12      3          70               668
# Zac Lomax                   8      0           9                56
# Zane Tetevano               4      1         234              2302
#
#                        kick_return_metres  post_contact_metres  ...  offloads  \
# name                                                            ...
# Aaron Gray                              0                   14  ...         0
# Aaron Woods                           175                 1243  ...        33
# Adam Blair                             41                  469  ...        30
# Adam Doueihi                           85                  196  ...         6
# Adam Elliott                           98                  629  ...         7
# Adam Reynolds                           1                  113  ...         7
# Addin Fonua-blake                     616                 1239  ...        13
# Agnatius Paasi                        381                  810  ...        24
# Aidan Guerra                           19                  937  ...         4
# Aidan Sezer                             6                  103  ...         3
# Aiden Tolman                          100                  707  ...         5
# Akuila Uate                           263                  450  ...         1
# Albert Vete                            73                   66  ...         3
# Alex Glenn                              6                  653  ...         4
# Alex Johnston                         534                  392  ...         9
# Alex Twal                             460                  608  ...         3
# Alexander Brimson                     230                  311  ...         3
# Andrew Fifita                         410                  958  ...        70
# Andrew McCullough                       0                  287  ...         0
# Angus Crichton                         34                 1003  ...        36
# Anthony Don                           488                  569  ...         5
# Anthony Gelling                         0                  187  ...         7
# Anthony Milford                       120                  360  ...        42
# Antonio Winterstein                   199                  619  ...         6
# Apisai Koroisau                         6                  190  ...         3
# Ashley Taylor                           2                  155  ...        26
# Asipeli Fine                           23                   79  ...         0
# Ata Hingano                             0                   52  ...         5
# Ava Seumanufagai                      167                  324  ...         0
# Beau Scott                              0                  114  ...         0
# ...                                   ...                  ...  ...       ...
# Tohu Harris                            21                  723  ...        14
# Tom Opacic                             13                  227  ...         5
# Tom Starling                            0                    0  ...         0
# Tom Trbojevic                         882                  930  ...        32
# Tom Wright                              0                   50  ...         3
# Tony Williams                           0                  181  ...         3
# Trent Hodkinson                        10                   56  ...         4
# Trent Merrin                          330                  879  ...        27
# Tui Kamikamica                         40                   93  ...         0
# Tuimoala Lolohea                      248                  190  ...         4
# Tyrell Fuimaono                         0                  105  ...         4
# Tyrone May                              0                   54  ...         8
# Tyrone Peachey                        198                  647  ...        16
# Tyrone Phillips                        71                  285  ...         4
# Tyronne Roberts-davis                  20                   16  ...         0
# Tyson Frizell                          10                  863  ...        20
# Tyson Gamble                            0                   20  ...         1
# Valentine Holmes                     1147                  857  ...        13
# Victor Radley                          59                  407  ...        13
# Viliame Kikau                          62                 1243  ...        40
# Wade Graham                            57                  515  ...        19
# Waqa Blake                              2                  336  ...        13
# Wayde Egan                              0                   54  ...         4
# Will Chambers                          31                  466  ...        13
# Will Hopoate                          651                 1069  ...        42
# Will Matthews                           0                  161  ...        10
# Will Smith                            172                  158  ...         4
# Young Tonumaipea                       19                  193  ...         0
# Zac Lomax                               2                   21  ...         0
# Zane Tetevano                         479                  847  ...         4
#
#                        passes  tackles_made  tackles_missed  \
# name
# Aaron Gray                  3            24               3
# Aaron Woods                86           625              24
# Adam Blair                110           660              64
# Adam Doueihi              112           117              11
# Adam Elliott               52           583              50
# Adam Reynolds             702           379              49
# Addin Fonua-blake          15           541              35
# Agnatius Paasi             16           498              55
# Aidan Guerra               45           954              76
# Aidan Sezer               603           279              59
# Aiden Tolman               65           513              22
# Akuila Uate                19            52              19
# Albert Vete                 3            31               3
# Alex Glenn                133           629              82
# Alex Johnston             261           110              18
# Alex Twal                   3           569              13
# Alexander Brimson         335           229              28
# Andrew Fifita              26           684              35
# Andrew McCullough        1783           884              41
# Angus Crichton             56           750              51
# Anthony Don                87            46              14
# Anthony Gelling            12            57              12
# Anthony Milford           639           285              57
# Antonio Winterstein        29            90              14
# Apisai Koroisau          1096           536              52
# Ashley Taylor             880           377              66
# Asipeli Fine                1            65               8
# Ata Hingano               205            98              20
# Ava Seumanufagai            3           197               5
# Beau Scott                  5           126              10
# ...                       ...           ...             ...
# Tohu Harris                66           547              39
# Tom Opacic                 31           127              10
# Tom Starling               27             9               0
# Tom Trbojevic             331            96              35
# Tom Wright                 38            41               9
# Tony Williams               7            69               6
# Trent Hodkinson           541           202              42
# Trent Merrin               37           601              47
# Tui Kamikamica              2            57               2
# Tuimoala Lolohea           87            19               6
# Tyrell Fuimaono            15            55              12
# Tyrone May                238           155              12
# Tyrone Peachey            354           263              42
# Tyrone Phillips            36            31               9
# Tyronne Roberts-davis       0             5               2
# Tyson Frizell              29           660              33
# Tyson Gamble               19            25               5
# Valentine Holmes          274            83              35
# Victor Radley             297           579              52
# Viliame Kikau              38           501              78
# Wade Graham               157           342              39
# Waqa Blake                 45           158              20
# Wayde Egan                390           187              10
# Will Chambers              22           247              49
# Will Hopoate              363           247              41
# Will Matthews               6           323              34
# Will Smith                395           238              22
# Young Tonumaipea           14            52              10
# Zac Lomax                   5            21               1
# Zane Tetevano              42           514              22
#
#                        ineffective_tackles  kicks  kicking_metres  errors  \
# name
# Aaron Gray                               2      0               0       2
# Aaron Woods                             21      0               0      14
# Adam Blair                              18      0               0      12
# Adam Doueihi                             8     36             983       4
# Adam Elliott                            27      0               0       6
# Adam Reynolds                           24    259            7332      11
# Addin Fonua-blake                       19      1              17      11
# Agnatius Paasi                          15      2              30       9
# Aidan Guerra                            35      2              32       6
# Aidan Sezer                             11    131            3386      16
# Aiden Tolman                            13      0               0       2
# Akuila Uate                              4      0               0      15
# Albert Vete                              1      0               0       0
# Alex Glenn                              29      0               0       9
# Alex Johnston                            3      4              55      15
# Alex Twal                               16      0               0       2
# Alexander Brimson                       22     38             851      10
# Andrew Fifita                           18      0               0      14
# Andrew McCullough                       20     31             969       6
# Angus Crichton                          30      3              63      25
# Anthony Don                              6      6             139      19
# Anthony Gelling                          3      1              14       4
# Anthony Milford                         23    279            8701      24
# Antonio Winterstein                      2      0               0       4
# Apisai Koroisau                         28      6             131      11
# Ashley Taylor                           31    247            6663      39
# Asipeli Fine                             2      0               0       1
# Ata Hingano                             12      2               8       6
# Ava Seumanufagai                         6      0               0       1
# Beau Scott                               4      0               0       0
# ...                                    ...    ...             ...     ...
# Tohu Harris                             17      5              75       4
# Tom Opacic                              10      2              21       3
# Tom Starling                             0      0               0       1
# Tom Trbojevic                            5     26             376      32
# Tom Wright                               3      2              49       3
# Tony Williams                            4      0               0       2
# Trent Hodkinson                         20     35             988       6
# Trent Merrin                            17      0               0      10
# Tui Kamikamica                           3      0               0       1
# Tuimoala Lolohea                         1      7             153       2
# Tyrell Fuimaono                          0      0               0       4
# Tyrone May                               5      7             129       2
# Tyrone Peachey                          13     15             214      18
# Tyrone Phillips                          1      0               0       9
# Tyronne Roberts-davis                    0      1              20       1
# Tyson Frizell                           23      1              10      13
# Tyson Gamble                             1      8             212       1
# Valentine Holmes                         7     11             121      24
# Victor Radley                           27      0               0      11
# Viliame Kikau                           32      5              68      19
# Wade Graham                             22     42            1433      12
# Waqa Blake                              10      3              18      19
# Wayde Egan                               3      2               7       0
# Will Chambers                           14     20             412      21
# Will Hopoate                            20      6              86      18
# Will Matthews                           10      0               0      10
# Will Smith                              15      6             138      12
# Young Tonumaipea                         4      1              10       4
# Zac Lomax                                3      0               0       3
# Zane Tetevano                           27      0               0       7
#
#                        penalties  sin_bins
# name
# Aaron Gray                     1         0
# Aaron Woods                   27         1
# Adam Blair                    11         1
# Adam Doueihi                   6         0
# Adam Elliott                  15         0
# Adam Reynolds                 19         0
# Addin Fonua-blake             17         1
# Agnatius Paasi                 9         0
# Aidan Guerra                  15         1
# Aidan Sezer                    8         0
# Aiden Tolman                  10         0
# Akuila Uate                    5         0
# Albert Vete                    0         0
# Alex Glenn                    15         0
# Alex Johnston                  0         0
# Alex Twal                      7         1
# Alexander Brimson              0         0
# Andrew Fifita                 33         0
# Andrew McCullough             14         1
# Angus Crichton                26         0
# Anthony Don                    1         0
# Anthony Gelling                2         0
# Anthony Milford               21         1
# Antonio Winterstein            2         0
# Apisai Koroisau                7         1
# Ashley Taylor                 16         1
# Asipeli Fine                   1         1
# Ata Hingano                    2         0
# Ava Seumanufagai               3         0
# Beau Scott                     4         0
# ...                          ...       ...
# Tohu Harris                   10         1
# Tom Opacic                     2         0
# Tom Starling                   0         0
# Tom Trbojevic                  2         0
# Tom Wright                     3         0
# Tony Williams                  1         0
# Trent Hodkinson                8         2
# Trent Merrin                  20         2
# Tui Kamikamica                 2         0
# Tuimoala Lolohea               0         0
# Tyrell Fuimaono                1         0
# Tyrone May                     0         1
# Tyrone Peachey                25         1
# Tyrone Phillips                0         0
# Tyronne Roberts-davis          0         0
# Tyson Frizell                 12         0
# Tyson Gamble                   0         0
# Valentine Holmes               2         0
# Victor Radley                 14         1
# Viliame Kikau                 11         1
# Wade Graham                    8         0
# Waqa Blake                     8         0
# Wayde Egan                     1         0
# Will Chambers                  8         0
# Will Hopoate                   3         0
# Will Matthews                 11         1
# Will Smith                     5         0
# Young Tonumaipea               3         0
# Zac Lomax                      2         0
# Zane Tetevano                 12         0
#
# [438 rows x 25 columns]

# %%
team_stats = player_stat_df.groupby('team').agg(sum)
#team_stats['total_run_metres'].sort_values(ascending=False)
slimmed_team_stats = team_stats[['points', 'tries', 'try_assists', 'total_runs', 'total_run_metres', 'tackles_made', 'tackles_missed', 'ineffective_tackles',
           'kicks', 'kicking_metres', 'errors', 'penalties']]
wins = final_standings[['wins', 'pts_differential', 'pts_scored', 'pts_allowed']]
team_stats = pd.concat([wins, slimmed_team_stats], axis=1, join='inner').sort_values(['wins', 'pts_differential'], ascending=[0,0])
team_stats['metres_per_kick'] = team_stats['kicking_metres'] / team_stats['kicks']
team_stats['metres_per_run'] = team_stats['total_run_metres'] / team_stats['total_runs']
team_stats['tackle_percentage'] = team_stats['tackles_made'] / (team_stats[['tackles_made', 'tackles_missed', 'ineffective_tackles']].sum(axis = 1))
team_stats[['wins', 'pts_scored', 'pts_allowed', 'tries', 'metres_per_run', 'total_run_metres', 'total_runs',
               'metres_per_kick', 'kicking_metres', 'kicks', 'tackle_percentage', 'tackles_made',
               'errors', 'penalties']]
#team_stats
# Out:
#             wins  pts_scored  pts_allowed  tries  metres_per_run  \
# Roosters      16         542          361     88        9.555332
# Storm         16         536          363     89        8.901842
# Rabbitohs     16         582          437     98        9.168663
# Sharks        16         519          423     87        8.852687
# Broncos       15         556          500     88        9.135204
# Panthers      15         517          461     82        8.959581
# Dragons       15         519          472     82        8.927717
# Warriors      15         472          447     80        9.154361
# Tigers        12         377          460     61        8.751688
# Raiders       10         563          540     93        9.198932
# Knights        9         414          607     73        8.449585
# Bulldogs       8         428          474     65        8.856198
# Cowboys        8         449          521     73        8.818542
# Titans         8         472          582     80        8.861295
# Sea Eagles     7         500          622     81        9.204175
# Eels           6         374          550     66        8.867740
#
#             total_run_metres  total_runs  metres_per_kick  kicking_metres  \
# Roosters               38078        3985        25.516930           11304
# Storm                  35278        3963        24.536300           10477
# Rabbitohs              38270        4174        26.138191           10403
# Sharks                 36898        4168        25.492754           10554
# Broncos                35810        3920        28.477124           13071
# Panthers               36797        4107        24.700483           10226
# Dragons                37300        4178        26.092135           11611
# Warriors               36947        4036        26.889423           11186
# Tigers                 34998        3999        25.450855           11911
# Raiders                34450        3745        25.313673            9442
# Knights                33604        3977        26.953883           11105
# Bulldogs               37506        4235        24.494407           10949
# Cowboys                35574        4034        21.863946            9642
# Titans                 34754        3922        24.221945            9713
# Sea Eagles             36154        3928        23.486842            8925
# Eels                   35267        3977        25.080963           11462
#
#             kicks  tackle_percentage  tackles_made  errors  penalties
# Roosters      443           0.877144          7925     276        198
# Storm         427           0.882131          7731     255        196
# Rabbitohs     398           0.877546          7582     242        202
# Sharks        414           0.869888          7381     245        201
# Broncos       459           0.872340          7749     207        189
# Panthers      414           0.862932          7624     237        226
# Dragons       445           0.880188          7846     246        169
# Warriors      416           0.872875          7855     219        206
# Tigers        468           0.865833          8583     233        197
# Raiders       373           0.863331          7315     233        225
# Knights       412           0.879970          8101     228        191
# Bulldogs      447           0.880417          7679     225        166
# Cowboys       441           0.872865          7614     255        181
# Titans        401           0.865776          7708     263        218
# Sea Eagles    380           0.870392          7320     239        212
# Eels          457           0.881210          8479     232        200

# %%
corr = team_stats.corr()
corr.style.background_gradient(cmap='coolwarm')

#neg(pts_allowed), pts_scored, tries, total_run_metres, metres_per_kick, kicking_metres, metres_per_run, total_runs,
# Out:
# <style  type="text/css" >
#     #T_f45d8380_b284_11e9_8edb_3af9d33c491erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow0_col1 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow0_col2 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow0_col3 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow0_col4 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow0_col5 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow0_col6 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow0_col7 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow0_col8 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow0_col9 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow0_col10 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow0_col11 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow0_col12 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow0_col13 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow0_col14 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow0_col15 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow0_col16 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow0_col17 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow0_col18 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow1_col0 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow1_col2 {
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow1_col4 {
#             background-color:  #da5a49;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow1_col5 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow1_col6 {
#             background-color:  #f08b6e;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow1_col7 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow1_col8 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow1_col9 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow1_col10 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow1_col11 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow1_col12 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow1_col13 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow1_col14 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow1_col15 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow1_col16 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow1_col17 {
#             background-color:  #f7ad90;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow1_col18 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow2_col0 {
#             background-color:  #ee8468;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow2_col1 {
#             background-color:  #d95847;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow2_col3 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow2_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow2_col5 {
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow2_col6 {
#             background-color:  #e26952;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow2_col7 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow2_col8 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow2_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow2_col10 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow2_col11 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow2_col12 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow2_col13 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow2_col14 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow2_col15 {
#             background-color:  #ecd3c5;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow2_col16 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow2_col17 {
#             background-color:  #f59d7e;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow2_col18 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f45d8380_b284_11e9_8edb_3af9d33c491erow3_col2 {
#             background-color:  #799cf8;

# %%
#We can see that tries, total_run_metres, metres_per_kick, low penalties, 

#Make some charts comparing points(for / against) to (metres_per_run, total_run_metres, tries, kicks, metres_per_kick,
#tackles_made, tackle_percentage)
#we don't want guys with high tackles_made...but high tackle_percentage

# %% [markdown]
# # Find each player's positions
# Will = max(position_id)
# Get rid of all players who played less than 12 games (half the season)

# %%
from scipy.stats import mode

position_df = player_stat_df[['name', 'position_id']]
modes = position_df.groupby('name')['position_id'].apply(lambda x: mode(x)[0][0]).reset_index().rename(columns={"position_id": "main_position"})
modes[:20]

player_stats_with_positions = pd.merge(modes, player_stats_grouped, how='left', on='name')

player_stats_with_positions = player_stats_with_positions.drop(columns=['match_id', 'position_id'])
player_stats_with_positions['metres_per_run'] = player_stats_with_positions['total_run_metres'] / player_stats_with_positions['total_runs']
player_stats_with_positions['metres_per_kick'] = player_stats_with_positions['kicking_metres'] / player_stats_with_positions['kicks']
player_stats_with_positions['tackle_percentage'] = player_stats_with_positions['tackles_made'] / (player_stats_with_positions['tackles_made'] + player_stats_with_positions['tackles_missed'] + player_stats_with_positions['ineffective_tackles'])

player_stats_with_positions.sort_values('name')
# Out:
#                       name  main_position  player_id  minutes_played  points  \
# 0               Aaron Gray              3         87            80.0       0
# 1              Aaron Woods              6       2346          1227.0       4
# 2               Adam Blair              9       4840          1390.0       4
# 3             Adam Doueihi             10       6192           674.0      26
# 4             Adam Elliott              9       1464          1063.0      16
# 5            Adam Reynolds              5       7245          1670.0     186
# 6        Addin Fonua-blake              6      12216          1152.0      12
# 7           Agnatius Paasi              6       4862           868.0      12
# 8             Aidan Guerra              8       4512          1674.0      20
# 9              Aidan Sezer              5        594          1380.0      21
# 10            Aiden Tolman              6        992           889.0       0
# 11             Akuila Uate              2       7620          1209.0      20
# 12             Albert Vete             10        471            64.0       0
# 13              Alex Glenn              8         40          1467.0      16
# 14           Alex Johnston              1       7266          1539.0      32
# 15               Alex Twal             10       9219           770.0       0
# 16       Alexander Brimson              4       1665          1179.0      28
# 17           Andrew Fifita              6       2369          1316.0      12
# 18       Andrew McCullough              7         63          1528.0      12
# 19          Angus Crichton              8      11638          1744.0      12
# 20             Anthony Don              2       2688          1924.0      60
# 21         Anthony Gelling             10       4095           268.0       8
# 22         Anthony Milford              4        456          1918.0      25
# 23     Antonio Winterstein              2       8272          1268.0      28
# 24         Apisai Koroisau              7       1989           910.0      12
# 25           Ashley Taylor              5       2599          1778.0      52
# 26            Asipeli Fine             10       2976           114.0       0
# 27             Ata Hingano             10        350           237.0       0
# 28        Ava Seumanufagai             10       1352           340.0       0
# 29              Beau Scott             10       3864           219.0       0
# ..                     ...            ...        ...             ...     ...
# 408            Tohu Harris              8       3744          1204.0       8
# 409             Tom Opacic              3       3108           508.0       4
# 410           Tom Starling             10        630            17.0       0
# 411          Tom Trbojevic              1       3322          1712.0      36
# 412             Tom Wright              4       2460           165.0       4
# 413          Tony Williams              8       2935           258.0       0
# 414        Trent Hodkinson             10       2736           891.0      52
# 415           Trent Merrin              6      12558          1007.0       8
# 416         Tui Kamikamica             10        860            93.0       0
# 417       Tuimoala Lolohea              1       3126           480.0      22
# 418        Tyrell Fuimaono             10       2046           250.0       0
# 419             Tyrone May             10       2600           382.0       4
# 420         Tyrone Peachey              4       2640          1617.0      36
# 421        Tyrone Phillips              2       5508           720.0      16
# 422  Tyronne Roberts-davis              2        604            80.0       0
# 423          Tyson Frizell              8       8547          1475.0      20
# 424           Tyson Gamble              4        470            80.0       0
# 425       Valentine Holmes              1      10856          1841.0     126
# 426          Victor Radley             10       9306           972.0      12
# 427          Viliame Kikau              8       7866          1593.0      20
# 428            Wade Graham              8       8092          1121.0      12
# 429             Waqa Blake              3       4564          1113.0      48
# 430             Wayde Egan             10       6960           310.0       4
# 431          Will Chambers              3       3179          1360.0      16
# 432           Will Hopoate              3       2016          1920.0      20
# 433          Will Matthews              8       8370           750.0       0
# 434             Will Smith             10       3731           650.0       4
# 435       Young Tonumaipea              3       4123           560.0      12
# 436              Zac Lomax              3        778            85.0       8
# 437          Zane Tetevano             10      10176           895.0       4
#
#      tries  total_runs  total_run_metres  kick_return_metres  \
# 0        0           8                53                   0
# 1        1         363              3185                 175
# 2        1         169              1296                  41
# 3        2          87               760                  85
# 4        4         240              1856                  98
# 5        4         146               861                   1
# 6        3         280              3029                 616
# 7        3         228              2205                 381
# 8        5         295              2365                  19
# 9        2          95               697                   6
# 10       0         229              1856                 100
# 11       5         174              1430                 263
# 12       0          22               212                  73
# 13       4         196              1799                   6
# 14       8         204              1980                 534
# 15       0         200              1968                 460
# 16       7         157              1447                 230
# 17       3         381              3072                 410
# 18       3          90               829                   0
# 19       3         340              2864                  34
# 20      15         251              2611                 488
# 21       2          45               445                   0
# 22       6         261              2090                 120
# 23       7         206              1898                 199
# 24       3          69               596                   6
# 25       3         171              1128                   2
# 26       0          25               213                  23
# 27       0          29               218                   0
# 28       0          92               865                 167
# 29       0          32               278                   0
# ..     ...         ...               ...                 ...
# 408      2         209              1888                  21
# 409      1          75               600                  13
# 410      0           1                 0                   0
# 411      9         386              3842                 882
# 412      1          25               219                   0
# 413      0          48               399                   0
# 414      2          45               237                  10
# 415      2         264              2452                 330
# 416      0          25               230                  40
# 417      1          73               655                 248
# 418      0          34               282                   0
# 419      1          45               268                   0
# 420      9         302              2577                 198
# 421      4         112               961                  71
# 422      0           9                61                  20
# 423      5         237              2282                  10
# 424      0           6                55                   0
# 425     21         318              3400                1147
# 426      3         166              1493                  59
# 427      5         313              2931                  62
# 428      3         191              1588                  57
# 429     12         131              1367                   2
# 430      1          24               163                   0
# 431      4         188              1703                  31
# 432      5         431              3854                 651
# 433      0          62               415                   0
# 434      1          76               652                 172
# 435      3          70               668                  19
# 436      0           9                56                   2
# 437      1         234              2302                 479
#
#      post_contact_metres  ...  tackles_missed  ineffective_tackles  kicks  \
# 0                     14  ...               3                    2      0
# 1                   1243  ...              24                   21      0
# 2                    469  ...              64                   18      0
# 3                    196  ...              11                    8     36
# 4                    629  ...              50                   27      0
# 5                    113  ...              49                   24    259
# 6                   1239  ...              35                   19      1
# 7                    810  ...              55                   15      2
# 8                    937  ...              76                   35      2
# 9                    103  ...              59                   11    131
# 10                   707  ...              22                   13      0
# 11                   450  ...              19                    4      0
# 12                    66  ...               3                    1      0
# 13                   653  ...              82                   29      0
# 14                   392  ...              18                    3      4
# 15                   608  ...              13                   16      0
# 16                   311  ...              28                   22     38
# 17                   958  ...              35                   18      0
# 18                   287  ...              41                   20     31
# 19                  1003  ...              51                   30      3
# 20                   569  ...              14                    6      6
# 21                   187  ...              12                    3      1
# 22                   360  ...              57                   23    279
# 23                   619  ...              14                    2      0
# 24                   190  ...              52                   28      6
# 25                   155  ...              66                   31    247
# 26                    79  ...               8                    2      0
# 27                    52  ...              20                   12      2
# 28                   324  ...               5                    6      0
# 29                   114  ...              10                    4      0
# ..                   ...  ...             ...                  ...    ...
# 408                  723  ...              39                   17      5
# 409                  227  ...              10                   10      2
# 410                    0  ...               0                    0      0
# 411                  930  ...              35                    5     26
# 412                   50  ...               9                    3      2
# 413                  181  ...               6                    4      0
# 414                   56  ...              42                   20     35
# 415                  879  ...              47                   17      0
# 416                   93  ...               2                    3      0
# 417                  190  ...               6                    1      7
# 418                  105  ...              12                    0      0
# 419                   54  ...              12                    5      7
# 420                  647  ...              42                   13     15
# 421                  285  ...               9                    1      0
# 422                   16  ...               2                    0      1
# 423                  863  ...              33                   23      1
# 424                   20  ...               5                    1      8
# 425                  857  ...              35                    7     11
# 426                  407  ...              52                   27      0
# 427                 1243  ...              78                   32      5
# 428                  515  ...              39                   22     42
# 429                  336  ...              20                   10      3
# 430                   54  ...              10                    3      2
# 431                  466  ...              49                   14     20
# 432                 1069  ...              41                   20      6
# 433                  161  ...              34                   10      0
# 434                  158  ...              22                   15      6
# 435                  193  ...              10                    4      1
# 436                   21  ...               1                    3      0
# 437                  847  ...              22                   27      0
#
#      kicking_metres  errors  penalties  sin_bins  metres_per_run  \
# 0                 0       2          1         0        6.625000
# 1                 0      14         27         1        8.774105
# 2                 0      12         11         1        7.668639
# 3               983       4          6         0        8.735632
# 4                 0       6         15         0        7.733333
# 5              7332      11         19         0        5.897260
# 6                17      11         17         1       10.817857
# 7                30       9          9         0        9.671053
# 8                32       6         15         1        8.016949
# 9              3386      16          8         0        7.336842
# 10                0       2         10         0        8.104803
# 11                0      15          5         0        8.218391
# 12                0       0          0         0        9.636364
# 13                0       9         15         0        9.178571
# 14               55      15          0         0        9.705882
# 15                0       2          7         1        9.840000
# 16              851      10          0         0        9.216561
# 17                0      14         33         0        8.062992
# 18              969       6         14         1        9.211111
# 19               63      25         26         0        8.423529
# 20              139      19          1         0       10.402390
# 21               14       4          2         0        9.888889
# 22             8701      24         21         1        8.007663
# 23                0       4          2         0        9.213592
# 24              131      11          7         1        8.637681
# 25             6663      39         16         1        6.596491
# 26                0       1          1         1        8.520000
# 27                8       6          2         0        7.517241
# 28                0       1          3         0        9.402174
# 29                0       0          4         0        8.687500
# ..              ...     ...        ...       ...             ...
# 408              75       4         10         1        9.033493
# 409              21       3          2         0        8.000000
# 410               0       1          0         0        0.000000
# 411             376      32          2         0        9.953368
# 412              49       3          3         0        8.760000
# 413               0       2          1         0        8.312500
# 414             988       6          8         2        5.266667
# 415               0      10         20         2        9.287879
# 416               0       1          2         0        9.200000
# 417             153       2          0         0        8.972603
# 418               0       4          1         0        8.294118
# 419             129       2          0         1        5.955556
# 420             214      18         25         1        8.533113
# 421               0       9          0         0        8.580357
# 422              20       1          0         0        6.777778
# 423              10      13         12         0        9.628692
# 424             212       1          0         0        9.166667
# 425             121      24          2         0       10.691824
# 426               0      11         14         1        8.993976
# 427              68      19         11         1        9.364217
# 428            1433      12          8         0        8.314136
# 429              18      19          8         0       10.435115
# 430               7       0          1         0        6.791667
# 431             412      21          8         0        9.058511
# 432              86      18          3         0        8.941995
# 433               0      10         11         1        6.693548
# 434             138      12          5         0        8.578947
# 435              10       4          3         0        9.542857
# 436               0       3          2         0        6.222222
# 437               0       7         12         0        9.837607
#
#      metres_per_kick  tackle_percentage
# 0                NaN           0.827586
# 1                NaN           0.932836
# 2                NaN           0.889488
# 3          27.305556           0.860294
# 4                NaN           0.883333
# 5          28.308880           0.838496
# 6          17.000000           0.909244
# 7          15.000000           0.876761
# 8          16.000000           0.895775
# 9          25.847328           0.799427
# 10               NaN           0.936131
# 11               NaN           0.693333
# 12               NaN           0.885714
# 13               NaN           0.850000
# 14         13.750000           0.839695
# 15               NaN           0.951505
# 16         22.394737           0.820789
# 17               NaN           0.928087
# 18         31.258065           0.935450
# 19         21.000000           0.902527
# 20         23.166667           0.696970
# 21         14.000000           0.791667
# 22         31.186380           0.780822
# 23               NaN           0.849057
# 24         21.833333           0.870130
# 25         26.975709           0.795359
# 26               NaN           0.866667
# 27          4.000000           0.753846
# 28               NaN           0.947115
# 29               NaN           0.900000
# ..               ...                ...
# 408        15.000000           0.907131
# 409        10.500000           0.863946
# 410              NaN           1.000000
# 411        14.461538           0.705882
# 412        24.500000           0.773585
# 413              NaN           0.873418
# 414        28.228571           0.765152
# 415              NaN           0.903759
# 416              NaN           0.919355
# 417        21.857143           0.730769
# 418              NaN           0.820896
# 419        18.428571           0.901163
# 420        14.266667           0.827044
# 421              NaN           0.756098
# 422        20.000000           0.714286
# 423        10.000000           0.921788
# 424        26.500000           0.806452
# 425        11.000000           0.664000
# 426              NaN           0.879939
# 427        13.600000           0.819967
# 428        34.119048           0.848635
# 429         6.000000           0.840426
# 430         3.500000           0.935000
# 431        20.600000           0.796774
# 432        14.333333           0.801948
# 433              NaN           0.880109
# 434        23.000000           0.865455
# 435        10.000000           0.787879
# 436              NaN           0.840000
# 437              NaN           0.912966
#
# [438 rows x 28 columns]

# %% [markdown]
# # Rank players on important stats..group by position

# %%
player_stats_with_positions = player_stats_with_positions[player_stats_with_positions['minutes_played'] > 800]
#stats_positions_merged.shape
main_stats = ['name', 'main_position', 'minutes_played', 'tries', 'try_assists', 'total_run_metres', 'total_runs', 'metres_per_run', 'kicks', 'kicking_metres', 'metres_per_kick', 'tackles_made', 'tackle_percentage']

df_by_position = {}

for i in range(11):
    if i > 0:
        important_stats = player_stats_with_positions[main_stats]
        position_df = important_stats[important_stats['main_position'] == i]
        df_by_position[i] = position_df.sort_values(['total_run_metres', 'tries', 'metres_per_kick', 'total_runs', 'tackle_percentage'], ascending = [0,0,0,0, 0])
        #stat_leader_df.append(df_by_position[i].sort_values(['total_run_metres', 'tries', 'metres_per_kick', 'total_runs', 'tackle_percentage'], ascending = [0,0,0,0, 0])[:5])

        
stat_leader_df = pd.DataFrame()      
for key in df_by_position:
    stat_leader_df = pd.concat([stat_leader_df, df_by_position[key][:5]])
stat_leader_df
# Out:
#                     name  main_position  minutes_played  tries  try_assists  \
# 174        James Tedesco              1          1748.0      9           11
# 354  Roger Tuivasa-sheck              1          1743.0      3            8
# 411        Tom Trbojevic              1          1712.0      9           14
# 425     Valentine Holmes              1          1841.0     21            8
# 292        Matthew Dufty              1          1893.0     12            8
# 37        Blake Ferguson              2          1918.0     17            4
# 128      George Jennings              2          2746.0     15            0
# 237          Ken Maumalo              2          1760.0      5            0
# 80           Corey Oates              2          1702.0     18            2
# 254           Kyle Feldt              2          1920.0     14            2
# 432         Will Hopoate              3          1920.0      5            7
# 114        Esan Marsters              3          1928.0      3            7
# 116          Euan Aitken              3          1765.0     10            1
# 350        Ricky Leutele              3          1727.0      3            5
# 90            Dane Gagai              3          1759.0      3           10
# 420       Tyrone Peachey              4          1617.0      9            6
# 58       Cameron Munster              4          1671.0      5           15
# 22       Anthony Milford              4          1918.0      6           12
# 79          Corey Norman              4          1823.0      4           12
# 36          Blake Austin              4          1576.0      5            7
# 272          Luke Brooks              5          1918.0      5           10
# 88     Daly Cherry-Evans              5          1930.0      8           15
# 246        Kodi Nikorima              5          1727.0      9            9
# 200   Johnathan Thurston              5          1920.0      3           23
# 379        Shaun Johnson              5          1430.0      4           14
# 101        David Klemmer              6          1244.0      0            0
# 284        Martin Taupau              6          1222.0      0            1
# 294        Matthew Lodge              6          1128.0      3            1
# 1            Aaron Woods              6          1227.0      1            0
# 17         Andrew Fifita              6          1316.0      3            2
# 89           Damien Cook              7          1736.0      4            8
# 140           Issac Luke              7          1559.0      5            2
# 57       Cameron McInnes              7          1860.0      3            6
# 382        Siliva Havili              7          1052.0      3            2
# 384          Sione Katoa              7          1635.0      3            5
# 427        Viliame Kikau              8          1593.0      5            1
# 19        Angus Crichton              8          1744.0      3            1
# 199          John Sutton              8          1842.0      4            5
# 138            Isaah Yeo              8          1757.0      3            2
# 395           Tariq Sims              8          1770.0      7            2
# 183      Jason Taumalolo              9          1430.0      4            1
# 164       Jake Trbojevic              9          1801.0      7            3
# 158            Jai Arrow              9          1146.0      3            0
# 361          Sam Burgess              9          1402.0      1            2
# 223         Josh Papalii              9          1480.0      5            2
# 194       Joe Ofahengaue             10          1160.0      3            0
# 262        Leeson Ah Mau             10           902.0      1            0
# 437        Zane Tetevano             10           895.0      1            0
# 173          James Tamou             10           936.0      2            0
# 299     Michael Chee-Kam             10          1270.0      3            1
#
#      total_run_metres  total_runs  metres_per_run  kicks  kicking_metres  \
# 174              4202         377       11.145889      6              86
# 354              4045         391       10.345269      2              22
# 411              3842         386        9.953368     26             376
# 425              3400         318       10.691824     11             121
# 292              3071         297       10.340067      4              69
# 37               4880         486       10.041152      5              73
# 128              4192         469        8.938166      1              19
# 237              3364         353        9.529745      3              52
# 80               3225         279       11.559140      3              59
# 254              3098         328        9.445122      3              58
# 432              3854         431        8.941995      6              86
# 114              3103         336        9.235119      9             102
# 116              2628         294        8.938776      1               3
# 350              2598         280        9.278571     14             287
# 90               2546         281        9.060498      7             117
# 420              2577         302        8.533113     15             214
# 58               2121         266        7.973684    109            2411
# 22               2090         261        8.007663    279            8701
# 79               1971         242        8.144628    176            4655
# 36               1794         195        9.200000     78            2141
# 272              1988         244        8.147541    210            5434
# 88               1550         202        7.673267    243            6218
# 246              1548         157        9.859873     90            2384
# 200              1506         254        5.929134    211            4445
# 379              1304         164        7.951220    151            4112
# 101              3974         408        9.740196      2              32
# 284              3752         371       10.113208      3              32
# 294              3231         346        9.338150      0               0
# 1                3185         363        8.774105      0               0
# 17               3072         381        8.062992      0               0
# 89               2307         229       10.074236     12             304
# 140              1637         166        9.861446     30            1134
# 57               1509         153        9.862745     13             136
# 382              1271         124       10.250000     10             258
# 384              1180         137        8.613139     20             557
# 427              2931         313        9.364217      5              68
# 19               2864         340        8.423529      3              63
# 199              2755         301        9.152824      7              61
# 138              2694         283        9.519435      4              67
# 395              2462         275        8.952727      2              54
# 183              4104         408       10.058824      1               2
# 164              3133         373        8.399464      3              66
# 158              2974         324        9.179012      0               0
# 361              2930         332        8.825301      3              74
# 223              2888         310        9.316129      0               0
# 194              2876         309        9.307443      1              10
# 262              2567         253       10.146245      1              20
# 437              2302         234        9.837607      0               0
# 173              2164         219        9.881279      0               0
# 299              2110         239        8.828452      3              35
#
#      metres_per_kick  tackles_made  tackle_percentage
# 174        14.333333           114           0.802817
# 354        11.000000            66           0.600000
# 411        14.461538            96           0.705882
# 425        11.000000            83           0.664000
# 292        17.250000           102           0.713287
# 37         14.600000            81           0.764151
# 128        19.000000           243           0.826531
# 237        17.333333            69           0.726316
# 80         19.666667            75           0.669643
# 254        19.333333           139           0.827381
# 432        14.333333           247           0.801948
# 114        11.333333           322           0.827763
# 116         3.000000           360           0.841121
# 350        20.500000           234           0.844765
# 90         16.714286           344           0.785388
# 420        14.266667           263           0.827044
# 58         22.119266           399           0.819302
# 22         31.186380           285           0.780822
# 79         26.448864           350           0.784753
# 36         27.448718           301           0.798408
# 272        25.876190           361           0.729293
# 88         25.588477           442           0.838710
# 246        26.488889           404           0.819473
# 200        21.066351           327           0.743182
# 379        27.231788           315           0.793451
# 101        16.000000           542           0.923339
# 284        10.666667           671           0.912925
# 294              NaN           547           0.887987
# 1                NaN           625           0.932836
# 17               NaN           684           0.928087
# 89         25.333333           944           0.910318
# 140        37.800000           681           0.869732
# 57         10.461538          1062           0.936508
# 382        25.800000           574           0.905363
# 384        27.850000           561           0.894737
# 427        13.600000           501           0.819967
# 19         21.000000           750           0.902527
# 199         8.714286           598           0.904690
# 138        16.750000           727           0.924936
# 395        27.000000           600           0.874636
# 183         2.000000           635           0.873453
# 164        22.000000           967           0.937016
# 158              NaN           635           0.899433
# 361        24.666667           634           0.868493
# 223              NaN           644           0.900699
# 194        10.000000           648           0.923077
# 262        20.000000           539           0.945614
# 437              NaN           514           0.912966
# 173              NaN           620           0.930931
# 299        11.666667           558           0.855828

# %%
#1 --> compare Tedesco to Tuivasa-Sheck
#3 --> Leilua isn't in there
#4 --> Peachey vs. Munster vs. Milford
#6 --> Klemmer vs. Tapau vs. Lodge vs. Woods vs. Fifita
#8 --> Jackson isn't in there
#10 --> Jazz isn't in there

# %% [markdown]
# # Based off of position stats, make graphs compairing positions where there wasn't a clear 'best player'...or...the 'best player' should have been someone else

# %%
#First...We'll look at Centres and Second Rowers to see why Leilua and Jackson are in the team despite not being top in their positions

#Second...Well do deeper analysis into Tedesco vs. Tuivasa-Sheck...did Tuivasa-Sheck prevail because he played for a crappier team?
#These positions are running heavy so we'll focus on running stats

#Third...Same with Peachey / Munster / Milford...these positions require a bit of everything so we'll look at all stats

# %% [markdown]
# ### Centres

# %% [markdown]
# # Rank players based on how big an impact they had for their respective teams

# %% [markdown]
# The below formuala takes in a dictionary of players and their respective teams and returns a dataframe comparing a players' impacts on their teams overall statistical output

# %%
def compare_individual_contribution_to_team(player_dict):
    def find_team_stats(team_name, stat):
        stats = team_stats.loc[team_name]
        return stats[stat]
    
    individual_impact = {}

    for name, team in player_dict.items():
        individual_impact[name] = {}
        individual_impact[name]['name'] = name
        player_df = stat_leader_df[stat_leader_df['name'] == name]
        player_df = player_df[['name', 'tries', 'try_assists', 'total_run_metres', 'total_runs', 'kicks', 'kicking_metres', 'tackles_made']]
        i = 0
        while i < len(player_df.columns):
            try:
                combined_team_stat = find_team_stats(team, player_df.columns[i])
                percent_of_team_stat = player_df[player_df.columns[i]] / combined_team_stat
                individual_impact[name][player_df.columns[i]] = (percent_of_team_stat.item() * 100)
                i += 1
            except:
                i += 1
                continue

    comparison_dataframe = pd.DataFrame()
    for i in individual_impact:
        player_dataframe = pd.DataFrame([individual_impact[i]], columns=individual_impact[i].keys())
        comparison_dataframe = pd.concat([comparison_dataframe, player_dataframe])
    return comparison_dataframe.set_index('name').round(2)

# %% [markdown]
# # Compare rankings to team of the year

# %% [markdown]
# # Fullbacks

# %%
fullbacks = {'James Tedesco': 'Roosters', 'Roger Tuivasa-sheck': 'Warriors'}
compare_individual_contribution_to_team(fullbacks)
# Out:
#                      tries  try_assists  total_run_metres  total_runs  kicks  \
# name
# James Tedesco        10.23        14.67             11.04        9.46   1.35
# Roger Tuivasa-sheck   3.75        12.70             10.95        9.69   0.48
#
#                      kicking_metres  tackles_made
# name
# James Tedesco                  0.76          1.44
# Roger Tuivasa-sheck            0.20          0.84

# %% [markdown]
# # Five-Eighths

# %%
five_eights = {'Tyrone Peachey': 'Panthers', 'Cameron Munster': 'Storm', 'Anthony Milford': 'Broncos'}
compare_individual_contribution_to_team(five_eights)
# Out:
#                  tries  try_assists  total_run_metres  total_runs  kicks  \
# name
# Tyrone Peachey   10.98         9.84              7.00        7.35   3.62
# Cameron Munster   5.62        25.00              6.01        6.71  25.53
# Anthony Milford   6.82        20.69              5.84        6.66  60.78
#
#                  kicking_metres  tackles_made
# name
# Tyrone Peachey             2.09          3.45
# Cameron Munster           23.01          5.16
# Anthony Milford           66.57          3.68
